# %% [markdown]
# # Amazon Fine Food Reviews

# %% [markdown]
# This dataset consists of reviews of fine foods from amazon. The data span a period of more than 10 years, including all ~500,000 reviews up to October 2012. Reviews include product and user information, ratings, and a plain text review. It also includes reviews from all other Amazon categories.
#
# Dataset from Kaggle(https://www.kaggle.com/snap/amazon-fine-food-reviews

# %% [markdown]
# ## Reviews from Oct 1999 - Oct 2012
# - 568,454 reviews
# - 256,059 users
# - 74,258 products
# - 260 users with > 50 reviews

# %% [markdown]
# Gensim package for LDA topic modelling and pyLDAvis for visualization of LDA topic model

# %% [markdown]
# Another good resource for understanding LDA
#
# https://medium.com/analytics-vidhya/topic-modeling-using-gensim-lda-in-python-48eaa2344920

# %%
import pandas as pd
import numpy as np

import re
import string

import spacy

import gensim
from gensim import corpora

# For visualizations
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt

# %% [markdown]
# # Gensim Library
# Gensim is a Python library for topic modelling, document indexing and similarity retrieval with large corpora. Target audience is the natural language processing (NLP) and information retrieval (IR) community.

# %% [markdown]
# **Features**
#
# * All algorithms are memory-independent w.r.t. the corpus size (can process input larger than RAM, streamed, out-of-core)
#
# * Intuitive interfaces
#
# * easy to plug in your own input corpus/datastream (simple streaming API)
#
# * asy to extend with other Vector Space algorithms (simple transformation API)
#
# * Efficient multicore implementations of popular algorithms, such as online Latent Semantic Analysis (LSA/LSI/SVD), Latent Dirichlet Allocation (LDA), Random Projections (RP), Hierarchical Dirichlet Process (HDP) or word2vec deep learning.
#
# * Distributed computing: can run Latent Semantic Analysis and Latent Dirichlet Allocation on a cluster of computers.

# %%
#!pip install pyLDAvis

# %%
data = pd.read_csv("largedata/Reviews.csv")
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data.shape
# Out:
# (568454, 10)

# %%
for i in data.columns:
    print(f'no. of unique {i}, is {data[i].nunique()},')
    print()
# Out:
# no. of unique Id, is 568454,
#
# no. of unique ProductId, is 74258,
#
# no. of unique UserId, is 256059,
#
# no. of unique ProfileName, is 218416,
#
# no. of unique HelpfulnessNumerator, is 231,
#
# no. of unique HelpfulnessDenominator, is 234,
#
# no. of unique Score, is 5,
#
# no. of unique Time, is 3168,
#
# no. of unique Summary, is 295742,
#
# no. of unique Text, is 393579,

# %%
data["Score"].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: Score, dtype: int64

# %%
def clean_text(text ): 
    delete_dict = {sp_character: '' for sp_character in string.punctuation} 
    delete_dict[' '] = ' ' 
    table = str.maketrans(delete_dict)
    text1 = text.translate(table)
    #print('cleaned:'+text1)
    textArr= text1.split()
    text2 = ' '.join([w for w in textArr if ( not w.isdigit() and  ( not w.isdigit() and len(w)>3))]) 
    
    return text2.lower()

# %%
import nltk
nltk.download('stopwords') # run this one time
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data.isna().sum().sum()
# Out:
# 43

# %%
data.dropna(axis = 0, how ='any',inplace=True)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data['Text'] = data['Text'].apply(clean_text)
data['Num_words_text'] = data['Text'].apply(lambda x:len(str(x).split()))

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  have bought several vitality canned food produ...
# 1      Not as Advertised  product arrived labeled jumbo salted peanutsth...
# 2  "Delight" says it all  this confection that been around centuries lig...
# 3         Cough Medicine  looking secret ingredient robitussin believe h...
# 4            Great taffy  great taffy great price there wide assortment ...
#
#    Num_words_text
# 0              30
# 1              20
# 2              52
# 3              22
# 4              17

# %%
max_review_len  = data['Num_words_text'].max()
max_review_len
# Out:
# 2234

# %% [markdown]
# ### Sampling only short reviews where len is greater than 20 & less than 100

# %%
mask = (data['Num_words_text'] < 100) & (data['Num_words_text'] >=20)
data_sr = data[mask]
data_sr.shape
# Out:
# (373281, 11)

# %%
data_sr.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 5                     0                       0      4  1342051200
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  have bought several vitality canned food produ...
# 1      Not as Advertised  product arrived labeled jumbo salted peanutsth...
# 2  "Delight" says it all  this confection that been around centuries lig...
# 3         Cough Medicine  looking secret ingredient robitussin believe h...
# 5             Nice Taffy  wild hair taffy ordered this five pound taffy ...
#
#    Num_words_text
# 0              30
# 1              20
# 2              52
# 3              22
# 5              43

# %%
data_sr[["Score"]].groupby("Score").value_counts()
# Out:
# Score
# 1     36230
# 2     20910
# 3     29080
# 4     53413
# 5    233648
# dtype: int64

# %%
data_sr["Score"].value_counts()
# Out:
# 5    233648
# 4     53413
# 1     36230
# 3     29080
# 2     20910
# Name: Score, dtype: int64

# %%
data_sampled = data_sr.groupby('Score').apply(lambda x: x.sample(n=20000)).reset_index(drop = True)

data_sampled.head()
# Out:
#        Id   ProductId          UserId                  ProfileName  \
# 0  321929  B000LKU4VE  A21XAQ9670N7EV                         sage
# 1   19803  B0030VBRIU  A2PZQZKGAOYF76  Amy L. Shorter "AmyLynnB17"
# 2  237487  B0030H1WW0  A14EW4N6O2M6IM            Peek_Inside_Books
# 3  372101  B001DP4TRQ   AI19H9NRP9B5F                SES51 "Steve"
# 4  169558  B001397WV2   AOMO31D8U3OPH                 joyce sineni
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       4      1  1225843200
# 1                     2                       3      1  1318291200
# 2                     0                       0      1  1291420800
# 3                     0                       0      1  1327017600
# 4                     3                       5      1  1277424000
#
#                            Summary  \
# 0                   Not even close
# 1           *** CHOKING HAZARD ***
# 2                            Yuck!
# 3  Opinion:  Sweet Kerosene Flavor
# 4            My two cats hated it.
#
#                                                 Text  Num_words_text
# 0  decided that this could have word cheddar incl...              77
# 1  love happy baby products cereals puffs yogurt ...              37
# 2  wheres logic here machine brew instant coffee ...              68
# 3  sodastream diet fountain mist flavor smells li...              55
# 4  cats like this stuff thought would treat them ...              42

# %%
data_sampled.shape
# Out:
# (100000, 11)

# %%
data_sampled["Score"].value_counts()
# Out:
# 1    20000
# 2    20000
# 3    20000
# 4    20000
# 5    20000
# Name: Score, dtype: int64

# %% [markdown]
# ## Preprocess the Data

# %% [markdown]
# ### Removing the stopwords

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# function to remove stopwords
def remove_stopwords(text):
    textArr = text.split(' ')
    rem_text = " ".join([i for i in textArr if i not in stop_words])
    return rem_text

# remove stopwords from the text
data_sampled['Text']=data_sampled['Text'].apply(remove_stopwords)

# %%
data_sampled.head()
# Out:
#        Id   ProductId          UserId                  ProfileName  \
# 0  321929  B000LKU4VE  A21XAQ9670N7EV                         sage
# 1   19803  B0030VBRIU  A2PZQZKGAOYF76  Amy L. Shorter "AmyLynnB17"
# 2  237487  B0030H1WW0  A14EW4N6O2M6IM            Peek_Inside_Books
# 3  372101  B001DP4TRQ   AI19H9NRP9B5F                SES51 "Steve"
# 4  169558  B001397WV2   AOMO31D8U3OPH                 joyce sineni
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       4      1  1225843200
# 1                     2                       3      1  1318291200
# 2                     0                       0      1  1291420800
# 3                     0                       0      1  1327017600
# 4                     3                       5      1  1277424000
#
#                            Summary  \
# 0                   Not even close
# 1           *** CHOKING HAZARD ***
# 2                            Yuck!
# 3  Opinion:  Sweet Kerosene Flavor
# 4            My two cats hated it.
#
#                                                 Text  Num_words_text
# 0  decided could word cheddar included packaging ...              77
# 1  love happy baby products cereals puffs yogurt ...              37
# 2  wheres logic machine brew instant coffee thoug...              68
# 3  sodastream diet fountain mist flavor smells li...              55
# 4  cats like stuff thought would treat pricey org...              42

# %%
nlp = spacy.load('en_core_web_lg', disable=['parser', 'ner'])

def lemmatization(texts,allowed_postags=['NOUN', 'ADJ']): 
    output = []
    for sent in texts:
        doc = nlp(sent) 
        output.append([token.lemma_ for token in doc if token.pos_ in allowed_postags ])
    return output

# %%
text_list=data_sampled['Text'].tolist()
print(text_list[1])
# Out:
# love happy baby products cereals puffs yogurt melts baby food except gobble gobble even year choked really ticked year choked extremely thick lumpy cannot believe happy baby manufacturers sells stuff cant believe retailers stock

# %%
tokenized_reviews = lemmatization(text_list)
print(tokenized_reviews[1])
# Out:
# ['happy', 'baby', 'product', 'cereal', 'yogurt', 'baby', 'food', 'gobble', 'year', 'year', 'thick', 'lumpy', 'happy', 'baby', 'manufacturer', 'stuff', 'retailer']

# %%
print(tokenized_reviews[5])
# Out:
# ['love', 'artichoke', 'heart', 'dish', 'awful', 'texture', 'gritty', 'awful', 'can', 'friend', 'nasty', 'waste', 'time', 'money']

# %% [markdown]
# ## Create vocabulary dictionary and document term matrix

# %%
# Every row is a document
dictionary = corpora.Dictionary(tokenized_reviews)
doc_term_matrix = [dictionary.doc2bow(rev) for rev in tokenized_reviews]

# %%
doc_term_matrix
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 1),
#   (3, 2),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 2),
#   (8, 1),
#   (9, 2),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 2),
#   (14, 1),
#   (15, 1),
#   (16, 1),
#   (17, 1),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 1),
#   (22, 1)],
#  [(13, 1),
#   (16, 1),
#   (22, 2),
#   (23, 3),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 2),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1)],
#  [(19, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 3),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (42, 1),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 1),
#   (47, 1),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 2),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 1),
#   (56, 1),
#   (57, 1),
#   (58, 1),
#   (59, 1),
#   (60, 1)],
#  [(5, 1),
#   (38, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 2),
#   (66, 3),
#   (67, 2),
#   (68, 1),
#   (69, 1),
#   (70, 2),
#   (71, 1),
#   (72, 1),
#   (73, 1)],
#  [(16, 1),
#   (25, 1),
#   (74, 1),
#   (75, 2),
#   (76, 1),
#   (77, 1),
#   (78, 1),
#   (79, 1),
#   (80, 1),
#   (81, 1),
#   (82, 1),
#   (83, 1),
#   (84, 1)],
#  [(19, 1),
#   (43, 1),
#   (85, 1),
#   (86, 2),
#   (87, 1),
#   (88, 1),
#   (89, 1),
#   (90, 1),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (94, 1),
#   (95, 1)],
#  [(37, 1),
#   (39, 3),
#   (66, 1),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1),
#   (103, 1)],
#  [(66, 1), (92, 2), (100, 1), (104, 1), (105, 1), (106, 2)],
#  [(7, 1),
#   (13, 1),
#   (57, 1),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 1),
#   (113, 1),
#   (114, 1),
#   (115, 1),
#   (116, 1),
#   (117, 1)],
#  [(37, 1),
#   (78, 1),
#   (89, 1),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 1),
#   (124, 1),
#   (125, 1)],
#  [(11, 1),
#   (19, 1),
#   (37, 2),
#   (57, 1),
#   (73, 1),
#   (95, 1),
#   (126, 1),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 1)],
#  [(22, 1),
#   (37, 1),
#   (39, 3),
#   (73, 1),
#   (88, 1),
#   (92, 1),
#   (95, 1),
#   (135, 1),
#   (136, 1),
#   (137, 1),
#   (138, 1),
#   (139, 1),
#   (140, 1),
#   (141, 1),
#   (142, 1)],
#  [(109, 1),
#   (143, 2),
#   (144, 1),
#   (145, 3),
#   (146, 2),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 1),
#   (151, 1)],
#  [(87, 1), (152, 1), (153, 1), (154, 1), (155, 1), (156, 2), (157, 1)],
#  [(19, 1),
#   (91, 1),
#   (130, 1),
#   (158, 2),
#   (159, 1),
#   (160, 1),
#   (161, 1),
#   (162, 1)],
#  [(19, 1),
#   (25, 1),
#   (107, 1),
#   (128, 1),
#   (135, 2),
#   (136, 1),
#   (163, 1),
#   (164, 2),
#   (165, 1),
#   (166, 1),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1)],
#  [(13, 1),
#   (64, 1),
#   (73, 1),
#   (175, 1),
#   (176, 2),
#   (177, 1),
#   (178, 1),
#   (179, 1),
#   (180, 1),
#   (181, 1),
#   (182, 1),
#   (183, 1),
#   (184, 1)],
#  [(185, 1),
#   (186, 2),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 1),
#   (191, 2),
#   (192, 1),
#   (193, 2),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1)],
#  [(66, 2),
#   (78, 1),
#   (83, 1),
#   (158, 1),
#   (164, 1),
#   (198, 1),
#   (199, 2),
#   (200, 2),
#   (201, 1),
#   (202, 4),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1)],
#  [(13, 1), (19, 2), (25, 1), (89, 1), (210, 1), (211, 1), (212, 1), (213, 1)],
#  [(16, 2),
#   (51, 1),
#   (214, 1),
#   (215, 2),
#   (216, 1),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 1)],
#  [(13, 1),
#   (39, 1),
#   (73, 1),
#   (109, 1),
#   (229, 1),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (234, 1),
#   (235, 1),
#   (236, 1)],
#  [(13, 3),
#   (102, 1),
#   (104, 1),
#   (126, 1),
#   (172, 1),
#   (177, 2),
#   (186, 1),
#   (189, 1),
#   (237, 1),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 1),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 1),
#   (254, 1)],
#  [(13, 1),
#   (25, 1),
#   (73, 2),
#   (83, 1),
#   (102, 1),
#   (128, 2),
#   (184, 1),
#   (189, 1),
#   (220, 1),
#   (255, 1),
#   (256, 1),
#   (257, 1),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 1),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (272, 2),
#   (273, 1),
#   (274, 1),
#   (275, 1)],
#  [(102, 1),
#   (126, 2),
#   (204, 4),
#   (256, 1),
#   (267, 1),
#   (276, 4),
#   (277, 1),
#   (278, 1)],
#  [(25, 1),
#   (83, 1),
#   (130, 1),
#   (235, 1),
#   (279, 1),
#   (280, 1),
#   (281, 1),
#   (282, 1)],
#  [(37, 2),
#   (52, 1),
#   (66, 3),
#   (204, 1),
#   (271, 1),
#   (276, 1),
#   (283, 1),
#   (284, 1),
#   (285, 2)],
#  [(55, 2),
#   (222, 1),
#   (286, 1),
#   (287, 1),
#   (288, 1),
#   (289, 1),
#   (290, 2),
#   (291, 2),
#   (292, 1),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 2)],
#  [(79, 1),
#   (124, 1),
#   (171, 3),
#   (203, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 1),
#   (305, 1)],
#  [(11, 1),
#   (141, 3),
#   (263, 1),
#   (302, 2),
#   (306, 1),
#   (307, 1),
#   (308, 2),
#   (309, 2),
#   (310, 1),
#   (311, 1),
#   (312, 2),
#   (313, 1)],
#  [(13, 2),
#   (37, 4),
#   (47, 1),
#   (52, 1),
#   (58, 1),
#   (66, 1),
#   (79, 3),
#   (102, 3),
#   (164, 1),
#   (182, 1),
#   (256, 1),
#   (295, 1),
#   (312, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1),
#   (320, 1),
#   (321, 1),
#   (322, 1),
#   (323, 2),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 1),
#   (331, 1)],
#  [(13, 1),
#   (55, 1),
#   (60, 1),
#   (66, 1),
#   (94, 1),
#   (291, 1),
#   (299, 1),
#   (332, 1),
#   (333, 1),
#   (334, 1),
#   (335, 1)],
#  [(57, 1),
#   (141, 1),
#   (336, 1),
#   (337, 2),
#   (338, 1),
#   (339, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1),
#   (343, 1),
#   (344, 1)],
#  [(9, 2),
#   (78, 1),
#   (132, 1),
#   (267, 1),
#   (308, 2),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 1)],
#  [(13, 3),
#   (19, 1),
#   (22, 1),
#   (78, 2),
#   (89, 1),
#   (128, 1),
#   (161, 1),
#   (219, 1),
#   (272, 1),
#   (281, 1),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 1),
#   (359, 1),
#   (360, 1),
#   (361, 1),
#   (362, 1),
#   (363, 3),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1),
#   (370, 1),
#   (371, 1),
#   (372, 1),
#   (373, 1),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 1)],
#  [(22, 1),
#   (34, 1),
#   (39, 2),
#   (66, 1),
#   (118, 2),
#   (126, 1),
#   (130, 1),
#   (164, 1),
#   (173, 1),
#   (191, 1),
#   (330, 1),
#   (378, 1),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 2),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 1),
#   (388, 1)],
#  [(36, 1),
#   (143, 1),
#   (284, 1),
#   (308, 1),
#   (364, 1),
#   (389, 1),
#   (390, 1),
#   (391, 1),
#   (392, 1),
#   (393, 1),
#   (394, 1)],
#  [(9, 1),
#   (19, 1),
#   (73, 1),
#   (109, 3),
#   (128, 1),
#   (164, 1),
#   (222, 1),
#   (255, 1),
#   (353, 1),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 1),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 1)],
#  [(7, 1),
#   (13, 2),
#   (73, 1),
#   (86, 1),
#   (405, 1),
#   (406, 2),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1)],
#  [(13, 1), (109, 1), (149, 1), (411, 1), (412, 1), (413, 1), (414, 1)],
#  [(13, 1),
#   (226, 1),
#   (382, 2),
#   (391, 1),
#   (415, 1),
#   (416, 2),
#   (417, 1),
#   (418, 1),
#   (419, 1),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 1)],
#  [(79, 1), (109, 1), (281, 1), (425, 1), (426, 1), (427, 1)],
#  [(73, 1), (102, 1), (428, 1), (429, 2), (430, 1)],
#  [(13, 4),
#   (126, 1),
#   (154, 1),
#   (166, 1),
#   (300, 1),
#   (431, 1),
#   (432, 1),
#   (433, 1),
#   (434, 1),
#   (435, 1),
#   (436, 1),
#   (437, 1),
#   (438, 1)],
#  [(1, 1),
#   (13, 1),
#   (66, 1),
#   (73, 2),
#   (83, 1),
#   (104, 1),
#   (382, 1),
#   (423, 1),
#   (439, 1),
#   (440, 1),
#   (441, 1),
#   (442, 1)],
#  [(13, 3),
#   (73, 1),
#   (92, 1),
#   (105, 2),
#   (256, 1),
#   (336, 1),
#   (372, 1),
#   (443, 1),
#   (444, 1),
#   (445, 2),
#   (446, 3),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 1),
#   (451, 1)],
#  [(16, 1),
#   (73, 1),
#   (103, 1),
#   (214, 1),
#   (222, 2),
#   (350, 1),
#   (452, 1),
#   (453, 1),
#   (454, 1),
#   (455, 1),
#   (456, 1),
#   (457, 2),
#   (458, 1),
#   (459, 1),
#   (460, 1)],
#  [(53, 1),
#   (55, 1),
#   (58, 1),
#   (60, 1),
#   (242, 1),
#   (284, 1),
#   (317, 1),
#   (350, 1),
#   (360, 1),
#   (461, 2),
#   (462, 1),
#   (463, 2),
#   (464, 1),
#   (465, 1)],
#  [(37, 3),
#   (66, 2),
#   (78, 1),
#   (89, 1),
#   (93, 1),
#   (129, 1),
#   (186, 1),
#   (222, 1),
#   (260, 1),
#   (268, 1),
#   (344, 1),
#   (466, 1),
#   (467, 2),
#   (468, 1),
#   (469, 1),
#   (470, 1),
#   (471, 1),
#   (472, 1),
#   (473, 1)],
#  [(13, 1),
#   (16, 1),
#   (19, 1),
#   (37, 3),
#   (44, 1),
#   (48, 1),
#   (51, 1),
#   (66, 1),
#   (78, 1),
#   (91, 1),
#   (141, 1),
#   (235, 1),
#   (256, 1),
#   (291, 1),
#   (305, 2),
#   (351, 1),
#   (369, 1),
#   (420, 1),
#   (444, 1),
#   (465, 1),
#   (474, 1),
#   (475, 1),
#   (476, 2),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 1),
#   (482, 1),
#   (483, 1),
#   (484, 1)],
#  [(37, 1),
#   (89, 1),
#   (122, 1),
#   (159, 1),
#   (172, 1),
#   (423, 1),
#   (484, 1),
#   (485, 1),
#   (486, 1),
#   (487, 1),
#   (488, 1),
#   (489, 1),
#   (490, 1),
#   (491, 1),
#   (492, 1),
#   (493, 1)],
#  [(19, 1),
#   (22, 1),
#   (51, 3),
#   (73, 2),
#   (109, 1),
#   (111, 1),
#   (121, 1),
#   (128, 1),
#   (162, 1),
#   (180, 1),
#   (186, 1),
#   (494, 2),
#   (495, 1)],
#  [(66, 1),
#   (167, 1),
#   (226, 1),
#   (334, 1),
#   (496, 1),
#   (497, 1),
#   (498, 1),
#   (499, 1),
#   (500, 1),
#   (501, 1),
#   (502, 1),
#   (503, 1)],
#  [(79, 1),
#   (141, 1),
#   (147, 1),
#   (504, 1),
#   (505, 1),
#   (506, 1),
#   (507, 1),
#   (508, 1),
#   (509, 1),
#   (510, 1),
#   (511, 1),
#   (512, 1),
#   (513, 1),
#   (514, 1)],
#  [(23, 1),
#   (49, 1),
#   (89, 1),
#   (190, 1),
#   (431, 2),
#   (437, 1),
#   (515, 1),
#   (516, 1),
#   (517, 1),
#   (518, 1),
#   (519, 1),
#   (520, 1),
#   (521, 1),
#   (522, 1),
#   (523, 1),
#   (524, 1)],
#  [(13, 2),
#   (19, 1),
#   (78, 1),
#   (109, 1),
#   (120, 1),
#   (126, 1),
#   (177, 1),
#   (222, 1),
#   (237, 1),
#   (331, 1),
#   (338, 1),
#   (350, 2),
#   (391, 3),
#   (525, 1),
#   (526, 1),
#   (527, 1),
#   (528, 1),
#   (529, 1),
#   (530, 2),
#   (531, 2),
#   (532, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 1),
#   (541, 1),
#   (542, 1)],
#  [(126, 2),
#   (231, 1),
#   (266, 1),
#   (278, 1),
#   (305, 1),
#   (393, 2),
#   (537, 1),
#   (543, 1),
#   (544, 1),
#   (545, 1),
#   (546, 1),
#   (547, 1),
#   (548, 1)],
#  [(13, 2),
#   (124, 1),
#   (245, 1),
#   (364, 1),
#   (504, 1),
#   (549, 1),
#   (550, 1),
#   (551, 1)],
#  [(43, 1),
#   (52, 2),
#   (126, 1),
#   (267, 1),
#   (552, 1),
#   (553, 1),
#   (554, 1),
#   (555, 1),
#   (556, 1),
#   (557, 1)],
#  [(52, 1),
#   (126, 1),
#   (336, 1),
#   (558, 1),
#   (559, 3),
#   (560, 2),
#   (561, 1),
#   (562, 1),
#   (563, 2),
#   (564, 1),
#   (565, 1),
#   (566, 1),
#   (567, 1),
#   (568, 1)],
#  [(19, 1),
#   (34, 1),
#   (37, 5),
#   (60, 1),
#   (66, 1),
#   (128, 1),
#   (141, 1),
#   (222, 2),
#   (235, 1),
#   (329, 2),
#   (489, 1),
#   (569, 1),
#   (570, 4),
#   (571, 1),
#   (572, 1),
#   (573, 1),
#   (574, 2),
#   (575, 1),
#   (576, 1)],
#  [(13, 1),
#   (52, 1),
#   (55, 1),
#   (79, 1),
#   (81, 1),
#   (132, 1),
#   (172, 1),
#   (300, 1),
#   (462, 1),
#   (568, 1),
#   (577, 1),
#   (578, 1),
#   (579, 1),
#   (580, 2),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 2)],
#  [(79, 1),
#   (118, 4),
#   (139, 1),
#   (207, 2),
#   (272, 1),
#   (280, 2),
#   (407, 2),
#   (443, 1),
#   (518, 1),
#   (585, 1),
#   (586, 1),
#   (587, 1),
#   (588, 2),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 1),
#   (593, 1),
#   (594, 1),
#   (595, 1),
#   (596, 1),
#   (597, 2),
#   (598, 1)],
#  [(3, 1),
#   (105, 1),
#   (117, 1),
#   (189, 1),
#   (272, 1),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1)],
#  [(13, 1),
#   (16, 1),
#   (25, 4),
#   (49, 1),
#   (52, 2),
#   (65, 1),
#   (78, 1),
#   (82, 1),
#   (92, 1),
#   (110, 1),
#   (111, 2),
#   (126, 2),
#   (154, 1),
#   (168, 2),
#   (335, 1),
#   (457, 1),
#   (504, 1),
#   (535, 1),
#   (605, 1),
#   (606, 1),
#   (607, 2),
#   (608, 1),
#   (609, 1),
#   (610, 3),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1),
#   (618, 1),
#   (619, 1),
#   (620, 1),
#   (621, 1)],
#  [(5, 1),
#   (13, 1),
#   (72, 5),
#   (79, 1),
#   (126, 1),
#   (130, 1),
#   (219, 1),
#   (272, 2),
#   (539, 1),
#   (607, 2),
#   (622, 1),
#   (623, 3),
#   (624, 1),
#   (625, 1),
#   (626, 1),
#   (627, 1),
#   (628, 1),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 4),
#   (633, 1),
#   (634, 1)],
#  [(117, 1), (405, 1), (504, 1), (635, 1), (636, 1), (637, 1)],
#  [(13, 1),
#   (166, 1),
#   (330, 1),
#   (348, 1),
#   (424, 1),
#   (435, 1),
#   (489, 1),
#   (543, 1),
#   (578, 1),
#   (607, 1),
#   (638, 1),
#   (639, 1),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 3),
#   (644, 1),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 2)],
#  [(5, 1),
#   (12, 1),
#   (107, 1),
#   (110, 2),
#   (449, 1),
#   (498, 1),
#   (511, 1),
#   (551, 1),
#   (607, 1),
#   (627, 2),
#   (652, 4),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 1)],
#  [(29, 1),
#   (53, 1),
#   (55, 2),
#   (66, 1),
#   (90, 1),
#   (105, 1),
#   (186, 1),
#   (337, 1),
#   (479, 2),
#   (509, 1),
#   (658, 1),
#   (659, 1),
#   (660, 1),
#   (661, 1),
#   (662, 1),
#   (663, 1),
#   (664, 1)],
#  [(66, 1),
#   (73, 1),
#   (78, 1),
#   (79, 1),
#   (83, 1),
#   (92, 1),
#   (95, 1),
#   (203, 1),
#   (281, 1),
#   (350, 1),
#   (453, 1),
#   (665, 1),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 3),
#   (670, 1)],
#  [(19, 2),
#   (25, 3),
#   (132, 1),
#   (141, 1),
#   (334, 1),
#   (346, 3),
#   (504, 1),
#   (671, 1),
#   (672, 1),
#   (673, 1),
#   (674, 1),
#   (675, 4),
#   (676, 1)],
#  [(13, 1),
#   (19, 1),
#   (166, 1),
#   (242, 1),
#   (281, 1),
#   (305, 1),
#   (312, 1),
#   (435, 1),
#   (464, 2),
#   (465, 1)],
#  [(19, 1),
#   (74, 2),
#   (102, 1),
#   (126, 1),
#   (164, 2),
#   (171, 3),
#   (243, 1),
#   (353, 1),
#   (362, 1),
#   (489, 1),
#   (532, 1),
#   (677, 2),
#   (678, 1),
#   (679, 1),
#   (680, 1),
#   (681, 1),
#   (682, 1),
#   (683, 1)],
#  [(9, 1),
#   (13, 4),
#   (25, 1),
#   (186, 1),
#   (191, 1),
#   (346, 2),
#   (368, 1),
#   (571, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1),
#   (687, 1),
#   (688, 1),
#   (689, 1),
#   (690, 1)],
#  [(13, 1),
#   (73, 1),
#   (448, 1),
#   (449, 1),
#   (691, 1),
#   (692, 1),
#   (693, 2),
#   (694, 2)],
#  [(235, 1),
#   (340, 1),
#   (489, 1),
#   (504, 1),
#   (525, 2),
#   (629, 1),
#   (683, 1),
#   (695, 1),
#   (696, 1),
#   (697, 2)],
#  [(22, 1),
#   (37, 1),
#   (130, 2),
#   (277, 1),
#   (468, 1),
#   (486, 1),
#   (698, 1),
#   (699, 1)],
#  [(177, 1),
#   (266, 1),
#   (312, 1),
#   (510, 1),
#   (700, 4),
#   (701, 1),
#   (702, 1),
#   (703, 1),
#   (704, 1),
#   (705, 1)],
#  [(13, 2),
#   (66, 3),
#   (72, 1),
#   (80, 2),
#   (130, 1),
#   (132, 1),
#   (141, 2),
#   (186, 2),
#   (222, 1),
#   (241, 1),
#   (272, 1),
#   (308, 2),
#   (337, 1),
#   (360, 2),
#   (706, 1),
#   (707, 1),
#   (708, 2)],
#  [(13, 1),
#   (78, 1),
#   (222, 1),
#   (263, 1),
#   (266, 1),
#   (302, 1),
#   (305, 3),
#   (414, 1),
#   (461, 1),
#   (601, 3),
#   (611, 3),
#   (658, 1),
#   (671, 1),
#   (709, 1),
#   (710, 1),
#   (711, 2),
#   (712, 1),
#   (713, 1),
#   (714, 1),
#   (715, 1),
#   (716, 1),
#   (717, 1),
#   (718, 1),
#   (719, 1)],
#  [(13, 2),
#   (53, 2),
#   (157, 1),
#   (242, 1),
#   (317, 1),
#   (464, 1),
#   (720, 1),
#   (721, 1),
#   (722, 1)],
#  [(22, 1),
#   (83, 1),
#   (109, 1),
#   (281, 1),
#   (305, 1),
#   (502, 1),
#   (723, 1),
#   (724, 1),
#   (725, 1)],
#  [(66, 1), (93, 1), (102, 1), (158, 1), (394, 1)],
#  [(5, 1),
#   (25, 1),
#   (132, 1),
#   (157, 1),
#   (266, 2),
#   (300, 1),
#   (302, 1),
#   (364, 1),
#   (465, 2),
#   (726, 1),
#   (727, 1),
#   (728, 1),
#   (729, 1),
#   (730, 1),
#   (731, 1),
#   (732, 1),
#   (733, 1),
#   (734, 1),
#   (735, 2)],
#  [(78, 1),
#   (147, 1),
#   (204, 1),
#   (228, 1),
#   (266, 1),
#   (276, 1),
#   (299, 1),
#   (393, 1),
#   (601, 1),
#   (612, 1),
#   (720, 1),
#   (736, 1),
#   (737, 1),
#   (738, 1),
#   (739, 1),
#   (740, 1)],
#  [(13, 2),
#   (19, 1),
#   (38, 1),
#   (109, 1),
#   (130, 1),
#   (149, 1),
#   (171, 2),
#   (382, 1),
#   (400, 1),
#   (692, 2),
#   (733, 1),
#   (741, 1),
#   (742, 1),
#   (743, 1),
#   (744, 1),
#   (745, 1),
#   (746, 2),
#   (747, 1),
#   (748, 1),
#   (749, 1),
#   (750, 1)],
#  [(40, 1),
#   (73, 2),
#   (89, 1),
#   (100, 1),
#   (109, 1),
#   (337, 1),
#   (751, 1),
#   (752, 1),
#   (753, 1),
#   (754, 1),
#   (755, 1),
#   (756, 1),
#   (757, 1)],
#  [(25, 1),
#   (60, 1),
#   (79, 1),
#   (147, 1),
#   (340, 1),
#   (489, 1),
#   (510, 1),
#   (695, 1),
#   (758, 2),
#   (759, 1),
#   (760, 1),
#   (761, 2)],
#  [(55, 1),
#   (73, 1),
#   (128, 1),
#   (137, 1),
#   (272, 1),
#   (346, 1),
#   (403, 1),
#   (423, 1),
#   (668, 1),
#   (708, 2),
#   (752, 2),
#   (762, 1),
#   (763, 1),
#   (764, 1)],
#  [(13, 3),
#   (22, 1),
#   (78, 1),
#   (109, 2),
#   (278, 1),
#   (334, 1),
#   (453, 1),
#   (467, 1),
#   (566, 1),
#   (594, 1),
#   (765, 1),
#   (766, 1),
#   (767, 1),
#   (768, 1),
#   (769, 1),
#   (770, 1),
#   (771, 1),
#   (772, 1)],
#  [(37, 1), (73, 1), (109, 1), (157, 1), (305, 1), (773, 1), (774, 1)],
#  [(19, 1),
#   (52, 1),
#   (60, 1),
#   (78, 2),
#   (128, 1),
#   (276, 1),
#   (348, 1),
#   (462, 1),
#   (657, 1),
#   (728, 1),
#   (775, 1),
#   (776, 1),
#   (777, 1),
#   (778, 2),
#   (779, 1),
#   (780, 1)],
#  [(37, 1),
#   (47, 1),
#   (78, 1),
#   (317, 1),
#   (321, 1),
#   (476, 1),
#   (479, 1),
#   (509, 1),
#   (567, 1),
#   (671, 1),
#   (781, 1),
#   (782, 1)],
#  [(16, 1), (37, 1), (232, 1), (391, 1), (394, 1), (476, 1), (783, 1)],
#  [(37, 1),
#   (79, 1),
#   (118, 2),
#   (164, 2),
#   (203, 1),
#   (312, 1),
#   (360, 1),
#   (714, 1),
#   (784, 1),
#   (785, 1),
#   (786, 1),
#   (787, 1)],
#  [(98, 1),
#   (404, 1),
#   (788, 2),
#   (789, 1),
#   (790, 1),
#   (791, 1),
#   (792, 2),
#   (793, 1)],
#  [(25, 1),
#   (126, 1),
#   (164, 1),
#   (186, 2),
#   (278, 1),
#   (281, 1),
#   (304, 1),
#   (311, 1),
#   (393, 1),
#   (607, 1),
#   (656, 1),
#   (770, 1),
#   (794, 1),
#   (795, 1),
#   (796, 1)],
#  [(19, 1),
#   (55, 1),
#   (152, 1),
#   (166, 1),
#   (269, 1),
#   (312, 1),
#   (580, 1),
#   (671, 1),
#   (698, 1),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 1),
#   (801, 1)],
#  [(66, 1),
#   (73, 2),
#   (87, 1),
#   (243, 1),
#   (256, 1),
#   (337, 2),
#   (390, 1),
#   (420, 1),
#   (538, 1),
#   (623, 1),
#   (788, 4),
#   (802, 1),
#   (803, 1),
#   (804, 1),
#   (805, 1),
#   (806, 1)],
#  [(13, 2),
#   (20, 1),
#   (25, 1),
#   (65, 1),
#   (111, 1),
#   (167, 1),
#   (200, 1),
#   (353, 1),
#   (403, 1),
#   (407, 1),
#   (457, 1),
#   (467, 1),
#   (504, 1),
#   (578, 3),
#   (598, 1),
#   (692, 1),
#   (694, 1),
#   (708, 1),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 1),
#   (812, 1),
#   (813, 1),
#   (814, 1),
#   (815, 1)],
#  [(3, 1),
#   (13, 1),
#   (73, 2),
#   (272, 1),
#   (444, 1),
#   (489, 1),
#   (561, 1),
#   (816, 1),
#   (817, 1),
#   (818, 1),
#   (819, 1),
#   (820, 1),
#   (821, 1)],
#  [(13, 3),
#   (66, 3),
#   (132, 1),
#   (264, 2),
#   (277, 1),
#   (489, 1),
#   (578, 1),
#   (581, 2),
#   (601, 3),
#   (822, 2),
#   (823, 1),
#   (824, 1),
#   (825, 1),
#   (826, 1),
#   (827, 1),
#   (828, 1)],
#  [(22, 1),
#   (79, 1),
#   (147, 1),
#   (193, 1),
#   (525, 2),
#   (607, 1),
#   (629, 1),
#   (690, 1),
#   (695, 1),
#   (697, 1),
#   (829, 1),
#   (830, 1),
#   (831, 1),
#   (832, 1)],
#  [(13, 1),
#   (103, 1),
#   (132, 1),
#   (332, 1),
#   (407, 1),
#   (422, 1),
#   (509, 1),
#   (571, 1),
#   (727, 1),
#   (766, 1),
#   (833, 1),
#   (834, 1),
#   (835, 1),
#   (836, 1),
#   (837, 1),
#   (838, 1),
#   (839, 1),
#   (840, 1),
#   (841, 1),
#   (842, 2),
#   (843, 1),
#   (844, 1),
#   (845, 2),
#   (846, 1),
#   (847, 1),
#   (848, 1),
#   (849, 1),
#   (850, 1),
#   (851, 1),
#   (852, 1),
#   (853, 1),
#   (854, 1)],
#  [(58, 1),
#   (73, 1),
#   (105, 1),
#   (117, 1),
#   (330, 1),
#   (392, 1),
#   (574, 1),
#   (725, 1),
#   (741, 1),
#   (855, 1),
#   (856, 1),
#   (857, 1)],
#  [(13, 1),
#   (78, 1),
#   (91, 1),
#   (111, 1),
#   (128, 1),
#   (191, 1),
#   (532, 1),
#   (631, 1),
#   (729, 1),
#   (858, 1),
#   (859, 1),
#   (860, 1),
#   (861, 1),
#   (862, 1),
#   (863, 1)],
#  [(5, 1),
#   (34, 2),
#   (37, 1),
#   (128, 1),
#   (141, 1),
#   (144, 1),
#   (283, 1),
#   (330, 1),
#   (340, 1),
#   (344, 2),
#   (511, 1),
#   (754, 1),
#   (782, 1),
#   (864, 4),
#   (865, 1),
#   (866, 3),
#   (867, 1),
#   (868, 1)],
#  [(693, 1), (869, 1), (870, 1), (871, 1)],
#  [(13, 2),
#   (272, 1),
#   (302, 1),
#   (435, 1),
#   (698, 1),
#   (830, 1),
#   (863, 1),
#   (872, 1),
#   (873, 1),
#   (874, 1)],
#  [(11, 1),
#   (13, 1),
#   (16, 1),
#   (55, 1),
#   (60, 1),
#   (61, 1),
#   (78, 1),
#   (109, 1),
#   (178, 1),
#   (184, 1),
#   (266, 1),
#   (281, 1),
#   (299, 1),
#   (368, 2),
#   (462, 1),
#   (875, 1),
#   (876, 1),
#   (877, 6),
#   (878, 1),
#   (879, 2)],
#  [(19, 1),
#   (66, 2),
#   (126, 1),
#   (128, 1),
#   (235, 1),
#   (331, 1),
#   (404, 1),
#   (407, 2),
#   (457, 1),
#   (511, 1),
#   (777, 1),
#   (877, 1),
#   (880, 1),
#   (881, 1),
#   (882, 1),
#   (883, 1)],
#  [(13, 1),
#   (23, 1),
#   (111, 1),
#   (215, 1),
#   (349, 1),
#   (492, 1),
#   (692, 2),
#   (732, 2),
#   (875, 1),
#   (884, 1),
#   (885, 1),
#   (886, 1),
#   (887, 1),
#   (888, 1),
#   (889, 1),
#   (890, 1)],
#  [(13, 1),
#   (25, 2),
#   (51, 1),
#   (55, 2),
#   (73, 1),
#   (74, 1),
#   (136, 1),
#   (187, 1),
#   (403, 1),
#   (462, 1),
#   (468, 1),
#   (489, 1),
#   (631, 1),
#   (728, 1),
#   (891, 1),
#   (892, 1),
#   (893, 2),
#   (894, 1),
#   (895, 2),
#   (896, 2),
#   (897, 1),
#   (898, 1)],
#  [(13, 1),
#   (25, 1),
#   (166, 1),
#   (186, 1),
#   (241, 1),
#   (242, 1),
#   (301, 1),
#   (302, 3),
#   (461, 3),
#   (464, 1),
#   (629, 1),
#   (744, 2),
#   (801, 1),
#   (812, 1),
#   (876, 2),
#   (890, 2),
#   (899, 1),
#   (900, 1),
#   (901, 1),
#   (902, 2),
#   (903, 1),
#   (904, 1),
#   (905, 1),
#   (906, 1)],
#  [(16, 1),
#   (76, 1),
#   (92, 1),
#   (184, 1),
#   (193, 1),
#   (299, 1),
#   (358, 2),
#   (428, 1),
#   (553, 1),
#   (576, 1),
#   (584, 1),
#   (671, 1),
#   (687, 1),
#   (907, 1),
#   (908, 1),
#   (909, 1),
#   (910, 2)],
#  [(13, 2),
#   (111, 1),
#   (409, 1),
#   (567, 1),
#   (688, 1),
#   (723, 1),
#   (911, 1),
#   (912, 1),
#   (913, 1),
#   (914, 1),
#   (915, 1),
#   (916, 1),
#   (917, 1),
#   (918, 1)],
#  [(13, 1),
#   (66, 2),
#   (91, 1),
#   (102, 1),
#   (109, 1),
#   (126, 2),
#   (135, 1),
#   (156, 1),
#   (177, 1),
#   (299, 1),
#   (332, 1),
#   (394, 1),
#   (449, 1),
#   (631, 1),
#   (880, 1),
#   (919, 1),
#   (920, 1),
#   (921, 1),
#   (922, 1),
#   (923, 1),
#   (924, 1)],
#  [(13, 2),
#   (44, 1),
#   (390, 1),
#   (449, 1),
#   (703, 1),
#   (756, 1),
#   (898, 1),
#   (925, 1),
#   (926, 1),
#   (927, 1)],
#  [(16, 1),
#   (78, 1),
#   (91, 1),
#   (413, 1),
#   (498, 1),
#   (581, 1),
#   (671, 1),
#   (731, 1),
#   (925, 1),
#   (928, 1),
#   (929, 1)],
#  [(109, 1),
#   (130, 1),
#   (272, 1),
#   (390, 1),
#   (403, 2),
#   (423, 1),
#   (468, 1),
#   (874, 1),
#   (930, 1),
#   (931, 1)],
#  [(66, 3), (78, 1), (86, 1), (109, 1), (446, 1), (895, 1)],
#  [(4, 1),
#   (13, 1),
#   (25, 1),
#   (89, 1),
#   (172, 1),
#   (175, 2),
#   (222, 1),
#   (272, 1),
#   (305, 1),
#   (349, 1),
#   (717, 2),
#   (932, 2),
#   (933, 2),
#   (934, 1),
#   (935, 1),
#   (936, 1)],
#  [(136, 2),
#   (147, 1),
#   (507, 1),
#   (532, 1),
#   (634, 2),
#   (680, 1),
#   (861, 1),
#   (937, 1),
#   (938, 1),
#   (939, 1),
#   (940, 1),
#   (941, 1),
#   (942, 1),
#   (943, 1),
#   (944, 1),
#   (945, 1)],
#  [(13, 1),
#   (22, 1),
#   (73, 1),
#   (78, 2),
#   (226, 1),
#   (242, 1),
#   (272, 1),
#   (800, 1),
#   (946, 1),
#   (947, 1),
#   (948, 1),
#   (949, 1)],
#  [(66, 2),
#   (73, 1),
#   (78, 1),
#   (101, 1),
#   (204, 1),
#   (256, 1),
#   (276, 1),
#   (391, 2),
#   (467, 1),
#   (675, 1),
#   (775, 1),
#   (895, 1),
#   (950, 1),
#   (951, 1),
#   (952, 1)],
#  [(13, 1),
#   (24, 2),
#   (60, 1),
#   (72, 1),
#   (73, 2),
#   (170, 1),
#   (299, 1),
#   (403, 1),
#   (423, 1),
#   (489, 1),
#   (538, 1),
#   (692, 1),
#   (804, 1),
#   (953, 1),
#   (954, 1),
#   (955, 1),
#   (956, 1),
#   (957, 1),
#   (958, 1),
#   (959, 1)],
#  [(24, 4),
#   (74, 1),
#   (78, 1),
#   (103, 1),
#   (128, 1),
#   (139, 1),
#   (189, 1),
#   (203, 1),
#   (232, 1),
#   (272, 1),
#   (300, 2),
#   (313, 2),
#   (340, 1),
#   (698, 1),
#   (777, 1),
#   (953, 1),
#   (954, 1),
#   (960, 2),
#   (961, 1),
#   (962, 1),
#   (963, 1),
#   (964, 1),
#   (965, 1)],
#  [(13, 1),
#   (66, 1),
#   (78, 2),
#   (358, 1),
#   (391, 2),
#   (420, 1),
#   (423, 1),
#   (478, 1),
#   (966, 1)],
#  [(37, 6),
#   (47, 1),
#   (52, 1),
#   (82, 1),
#   (87, 1),
#   (118, 1),
#   (128, 1),
#   (131, 1),
#   (132, 1),
#   (235, 1),
#   (265, 1),
#   (307, 1),
#   (318, 2),
#   (346, 1),
#   (350, 1),
#   (369, 1),
#   (415, 1),
#   (422, 2),
#   (424, 1),
#   (453, 1),
#   (486, 1),
#   (578, 1),
#   (670, 1),
#   (782, 1),
#   (783, 1),
#   (836, 1),
#   (843, 1),
#   (866, 2),
#   (967, 1),
#   (968, 1),
#   (969, 1),
#   (970, 1),
#   (971, 1),
#   (972, 1),
#   (973, 1),
#   (974, 1),
#   (975, 1)],
#  [(128, 1),
#   (350, 1),
#   (510, 1),
#   (623, 1),
#   (698, 1),
#   (756, 1),
#   (816, 1),
#   (976, 1)],
#  [(13, 5),
#   (37, 1),
#   (47, 2),
#   (53, 1),
#   (103, 1),
#   (186, 1),
#   (211, 1),
#   (222, 2),
#   (253, 1),
#   (305, 1),
#   (340, 1),
#   (345, 1),
#   (350, 1),
#   (489, 1),
#   (568, 1),
#   (873, 1),
#   (977, 1),
#   (978, 1),
#   (979, 1),
#   (980, 1),
#   (981, 1)],
#  [(66, 1),
#   (69, 1),
#   (83, 3),
#   (99, 1),
#   (111, 1),
#   (168, 1),
#   (260, 3),
#   (278, 1),
#   (420, 1),
#   (497, 1),
#   (504, 1),
#   (634, 1),
#   (697, 2),
#   (708, 3),
#   (803, 1),
#   (830, 1),
#   (899, 1),
#   (982, 1),
#   (983, 1)],
#  [(22, 1),
#   (92, 1),
#   (167, 1),
#   (231, 1),
#   (266, 1),
#   (305, 1),
#   (393, 1),
#   (504, 1),
#   (984, 2),
#   (985, 1),
#   (986, 1),
#   (987, 1),
#   (988, 1),
#   (989, 1),
#   (990, 1)],
#  [(60, 1),
#   (64, 1),
#   (118, 3),
#   (142, 1),
#   (232, 1),
#   (364, 2),
#   (390, 4),
#   (393, 1),
#   (576, 1),
#   (697, 4),
#   (897, 4),
#   (991, 1),
#   (992, 1),
#   (993, 2)],
#  [(25, 1),
#   (69, 1),
#   (171, 2),
#   (272, 1),
#   (282, 1),
#   (305, 2),
#   (308, 1),
#   (631, 1),
#   (720, 2),
#   (994, 1),
#   (995, 1)],
#  [(19, 1),
#   (25, 1),
#   (79, 1),
#   (191, 1),
#   (281, 1),
#   (486, 1),
#   (503, 1),
#   (996, 1),
#   (997, 2)],
#  [(38, 2),
#   (92, 1),
#   (95, 1),
#   (118, 2),
#   (135, 3),
#   (143, 1),
#   (167, 1),
#   (170, 1),
#   (206, 1),
#   (333, 1),
#   (393, 2),
#   (553, 1),
#   (576, 2),
#   (634, 1),
#   (739, 3),
#   (820, 1),
#   (998, 1),
#   (999, 1),
#   (1000, 1)],
#  [(13, 1),
#   (16, 1),
#   (127, 1),
#   (130, 1),
#   (132, 1),
#   (156, 1),
#   (369, 1),
#   (813, 1),
#   (874, 1),
#   (1001, 1),
#   (1002, 2),
#   (1003, 1)],
#  [(73, 1), (80, 1), (102, 2), (170, 1), (350, 1), (444, 2), (805, 1)],
#  [(13, 1),
#   (92, 1),
#   (128, 1),
#   (166, 1),
#   (186, 1),
#   (222, 1),
#   (340, 1),
#   (353, 1),
#   (750, 1),
#   (974, 1),
#   (1004, 1),
#   (1005, 1),
#   (1006, 1),
#   (1007, 1),
#   (1008, 1)],
#  [(25, 1),
#   (53, 1),
#   (78, 1),
#   (105, 1),
#   (136, 1),
#   (151, 1),
#   (232, 1),
#   (254, 1),
#   (748, 1),
#   (1009, 1),
#   (1010, 1),
#   (1011, 1)],
#  [(52, 1),
#   (78, 1),
#   (164, 1),
#   (203, 1),
#   (317, 1),
#   (442, 1),
#   (634, 1),
#   (838, 1),
#   (886, 1),
#   (1012, 1),
#   (1013, 1),
#   (1014, 1),
#   (1015, 1),
#   (1016, 1),
#   (1017, 1),
#   (1018, 1),
#   (1019, 1),
#   (1020, 1),
#   (1021, 1),
#   (1022, 1),
#   (1023, 1),
#   (1024, 1)],
#  [(13, 1),
#   (29, 2),
#   (239, 4),
#   (443, 2),
#   (568, 1),
#   (702, 1),
#   (796, 2),
#   (1025, 1),
#   (1026, 1),
#   (1027, 1),
#   (1028, 2),
#   (1029, 1),
#   (1030, 1),
#   (1031, 1),
#   (1032, 1)],
#  [(13, 6),
#   (47, 1),
#   (48, 1),
#   (127, 1),
#   (132, 1),
#   (186, 3),
#   (295, 1),
#   (353, 1),
#   (359, 1),
#   (413, 1),
#   (451, 1),
#   (548, 1),
#   (657, 2),
#   (673, 1),
#   (713, 1),
#   (763, 2),
#   (920, 2),
#   (1033, 1),
#   (1034, 1),
#   (1035, 1),
#   (1036, 2),
#   (1037, 1),
#   (1038, 1),
#   (1039, 1),
#   (1040, 2),
#   (1041, 1),
#   (1042, 1),
#   (1043, 1),
#   (1044, 3)],
#  [(0, 1),
#   (13, 5),
#   (25, 1),
#   (27, 1),
#   (55, 1),
#   (299, 1),
#   (514, 1),
#   (1015, 1),
#   (1045, 1),
#   (1046, 1),
#   (1047, 1),
#   (1048, 1),
#   (1049, 1)],
#  [(19, 1), (308, 1), (679, 1), (757, 1), (1050, 1), (1051, 1)],
#  [(13, 1),
#   (47, 1),
#   (66, 1),
#   (164, 3),
#   (330, 1),
#   (393, 1),
#   (402, 1),
#   (525, 2),
#   (657, 1),
#   (698, 2),
#   (897, 1),
#   (1052, 1),
#   (1053, 1),
#   (1054, 1)],
#  [(19, 1),
#   (22, 1),
#   (48, 1),
#   (111, 1),
#   (423, 1),
#   (874, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 1),
#   (1058, 1)],
#  [(16, 3), (86, 1), (91, 1), (391, 1), (504, 1), (1059, 1)],
#  [(13, 2),
#   (51, 1),
#   (65, 1),
#   (92, 1),
#   (96, 3),
#   (154, 1),
#   (200, 1),
#   (337, 1),
#   (344, 1),
#   (703, 1),
#   (882, 1),
#   (932, 3),
#   (1037, 1),
#   (1060, 1),
#   (1061, 1),
#   (1062, 1),
#   (1063, 1),
#   (1064, 1),
#   (1065, 1)],
#  [(13, 1),
#   (55, 1),
#   (76, 4),
#   (175, 4),
#   (207, 1),
#   (239, 1),
#   (332, 1),
#   (443, 1),
#   (448, 1),
#   (497, 4),
#   (594, 1),
#   (910, 4),
#   (1066, 1),
#   (1067, 1),
#   (1068, 1),
#   (1069, 1),
#   (1070, 4),
#   (1071, 1)],
#  [(13, 3),
#   (19, 1),
#   (25, 1),
#   (79, 1),
#   (104, 1),
#   (110, 1),
#   (111, 1),
#   (113, 1),
#   (118, 1),
#   (141, 1),
#   (156, 1),
#   (198, 1),
#   (200, 1),
#   (222, 1),
#   (256, 1),
#   (259, 1),
#   (282, 1),
#   (299, 1),
#   (300, 1),
#   (364, 1),
#   (413, 1),
#   (514, 1),
#   (670, 1),
#   (694, 1),
#   (827, 1),
#   (926, 1),
#   (965, 1),
#   (1072, 1),
#   (1073, 1),
#   (1074, 1),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1),
#   (1078, 1),
#   (1079, 1),
#   (1080, 1),
#   (1081, 1),
#   (1082, 1),
#   (1083, 2),
#   (1084, 1),
#   (1085, 1),
#   (1086, 1),
#   (1087, 1),
#   (1088, 1)],
#  [(52, 1),
#   (78, 1),
#   (126, 1),
#   (173, 1),
#   (424, 1),
#   (507, 1),
#   (557, 1),
#   (803, 1),
#   (1089, 4),
#   (1090, 1),
#   (1091, 1),
#   (1092, 1),
#   (1093, 1),
#   (1094, 1),
#   (1095, 1),
#   (1096, 2),
#   (1097, 1)],
#  [(16, 1),
#   (73, 1),
#   (83, 1),
#   (86, 1),
#   (93, 1),
#   (203, 1),
#   (222, 1),
#   (299, 1),
#   (358, 1),
#   (499, 1),
#   (667, 1),
#   (804, 1),
#   (832, 1),
#   (971, 1),
#   (1024, 1),
#   (1059, 1),
#   (1098, 1),
#   (1099, 1),
#   (1100, 1),
#   (1101, 1),
#   (1102, 1)],
#  [(13, 1),
#   (19, 3),
#   (60, 1),
#   (86, 1),
#   (117, 1),
#   (127, 1),
#   (130, 1),
#   (132, 2),
#   (266, 1),
#   (294, 1),
#   (312, 1),
#   (350, 1),
#   (489, 2),
#   (560, 1),
#   (631, 1),
#   (697, 1),
#   (698, 1),
#   (722, 3),
#   (731, 1),
#   (792, 1),
#   (876, 1),
#   (1103, 1),
#   (1104, 1),
#   (1105, 1),
#   (1106, 2),
#   (1107, 1)],
#  [(78, 1),
#   (102, 1),
#   (330, 1),
#   (348, 1),
#   (827, 2),
#   (1108, 1),
#   (1109, 2),
#   (1110, 1)],
#  [(19, 2),
#   (22, 1),
#   (25, 1),
#   (60, 1),
#   (104, 2),
#   (142, 1),
#   (172, 1),
#   (200, 3),
#   (281, 2),
#   (358, 1),
#   (360, 1),
#   (457, 1),
#   (578, 2),
#   (629, 1),
#   (729, 1),
#   (863, 2),
#   (949, 1),
#   (1069, 1),
#   (1111, 1),
#   (1112, 1),
#   (1113, 1),
#   (1114, 1),
#   (1115, 1),
#   (1116, 1),
#   (1117, 1),
#   (1118, 1),
#   (1119, 1),
#   (1120, 1),
#   (1121, 1),
#   (1122, 1),
#   (1123, 3),
#   (1124, 2),
#   (1125, 1)],
#  [(19, 1),
#   (37, 2),
#   (91, 1),
#   (121, 1),
#   (140, 1),
#   (144, 1),
#   (261, 2),
#   (294, 1),
#   (345, 1),
#   (440, 1),
#   (489, 1),
#   (509, 1),
#   (532, 3),
#   (616, 1),
#   (703, 1),
#   (771, 1),
#   (1126, 1),
#   (1127, 1)],
#  [(58, 1),
#   (66, 1),
#   (92, 1),
#   (95, 1),
#   (351, 1),
#   (393, 1),
#   (778, 1),
#   (813, 1),
#   (1128, 1),
#   (1129, 1),
#   (1130, 1)],
#  [(13, 1),
#   (91, 1),
#   (112, 2),
#   (190, 1),
#   (337, 2),
#   (358, 1),
#   (364, 1),
#   (449, 1),
#   (514, 1),
#   (554, 1),
#   (616, 1),
#   (631, 2),
#   (788, 2),
#   (803, 2),
#   (919, 1),
#   (1038, 1),
#   (1073, 2),
#   (1131, 1),
#   (1132, 1),
#   (1133, 1),
#   (1134, 1)],
#  [(16, 1),
#   (19, 1),
#   (130, 1),
#   (157, 1),
#   (166, 3),
#   (266, 2),
#   (637, 1),
#   (757, 1),
#   (1135, 1),
#   (1136, 1),
#   (1137, 1),
#   (1138, 1),
#   (1139, 2)],
#  [(37, 3),
#   (39, 1),
#   (78, 1),
#   (129, 1),
#   (222, 1),
#   (299, 1),
#   (364, 1),
#   (479, 1),
#   (607, 1),
#   (744, 1)],
#  [(60, 1),
#   (83, 1),
#   (86, 2),
#   (214, 1),
#   (232, 1),
#   (330, 2),
#   (504, 2),
#   (697, 1),
#   (874, 1),
#   (1101, 1),
#   (1140, 1),
#   (1141, 1),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1),
#   (1146, 1),
#   (1147, 1),
#   (1148, 1)],
#  [(85, 1),
#   (157, 1),
#   (407, 1),
#   (435, 1),
#   (727, 1),
#   (738, 1),
#   (925, 1),
#   (1053, 1),
#   (1149, 1),
#   (1150, 1),
#   (1151, 1),
#   (1152, 1)],
#  [(9, 1),
#   (13, 1),
#   (27, 1),
#   (87, 1),
#   (103, 1),
#   (300, 1),
#   (308, 1),
#   (437, 1),
#   (883, 1),
#   (945, 1),
#   (1153, 1),
#   (1154, 1)],
#  [(3, 1),
#   (25, 1),
#   (95, 1),
#   (695, 1),
#   (874, 1),
#   (1051, 2),
#   (1155, 1),
#   (1156, 1),
#   (1157, 1)],
#  [(87, 1), (266, 1), (1158, 1)],
#  [(78, 1),
#   (94, 1),
#   (511, 1),
#   (559, 2),
#   (574, 1),
#   (729, 1),
#   (925, 1),
#   (1002, 1),
#   (1159, 1),
#   (1160, 1),
#   (1161, 1),
#   (1162, 1),
#   (1163, 1),
#   (1164, 1),
#   (1165, 1),
#   (1166, 1)],
#  [(66, 1),
#   (73, 1),
#   (91, 3),
#   (126, 1),
#   (285, 2),
#   (342, 1),
#   (407, 1),
#   (561, 1),
#   (1167, 1)],
#  [(73, 1), (167, 1)],
#  [(19, 1),
#   (25, 1),
#   (91, 1),
#   (135, 1),
#   (151, 1),
#   (424, 1),
#   (581, 1),
#   (731, 1),
#   (748, 1),
#   (750, 1),
#   (1168, 1),
#   (1169, 1)],
#  [(20, 2),
#   (55, 1),
#   (429, 2),
#   (580, 1),
#   (679, 1),
#   (720, 1),
#   (812, 1),
#   (1150, 1)],
#  [(37, 1),
#   (39, 1),
#   (73, 1),
#   (568, 1),
#   (748, 2),
#   (1170, 1),
#   (1171, 1),
#   (1172, 1),
#   (1173, 1)],
#  [(17, 1),
#   (20, 1),
#   (78, 2),
#   (109, 1),
#   (135, 1),
#   (444, 1),
#   (463, 1),
#   (601, 1),
#   (748, 1),
#   (818, 1),
#   (1174, 1)],
#  [(13, 3),
#   (20, 1),
#   (172, 1),
#   (272, 1),
#   (302, 1),
#   (305, 1),
#   (369, 1),
#   (461, 1),
#   (465, 2),
#   (511, 1),
#   (670, 1),
#   (833, 1),
#   (1175, 1)],
#  [(25, 1),
#   (126, 1),
#   (164, 1),
#   (186, 2),
#   (278, 1),
#   (281, 1),
#   (304, 1),
#   (311, 1),
#   (393, 1),
#   (607, 1),
#   (656, 1),
#   (770, 1),
#   (794, 1),
#   (795, 1),
#   (796, 1)],
#  [(61, 1),
#   (73, 1),
#   (93, 1),
#   (260, 1),
#   (469, 1),
#   (498, 1),
#   (514, 1),
#   (672, 1),
#   (918, 1),
#   (1103, 1),
#   (1176, 1),
#   (1177, 1),
#   (1178, 1),
#   (1179, 1),
#   (1180, 1),
#   (1181, 1)],
#  [(109, 1),
#   (631, 1),
#   (1182, 1),
#   (1183, 1),
#   (1184, 1),
#   (1185, 1),
#   (1186, 1),
#   (1187, 1),
#   (1188, 1),
#   (1189, 1),
#   (1190, 1),
#   (1191, 1),
#   (1192, 1)],
#  [(7, 1),
#   (78, 1),
#   (79, 2),
#   (117, 2),
#   (132, 1),
#   (136, 2),
#   (190, 1),
#   (193, 1),
#   (403, 1),
#   (437, 2),
#   (514, 1),
#   (670, 1),
#   (865, 1),
#   (1074, 1),
#   (1085, 1),
#   (1193, 1),
#   (1194, 1),
#   (1195, 1)],
#  [(37, 1),
#   (39, 1),
#   (66, 1),
#   (167, 1),
#   (378, 1),
#   (830, 1),
#   (836, 1),
#   (1196, 1),
#   (1197, 1),
#   (1198, 1),
#   (1199, 1)],
#  [(13, 1), (37, 3), (73, 1), (78, 1), (92, 1), (108, 1), (634, 1), (1199, 2)],
#  [(13, 1),
#   (66, 1),
#   (73, 1),
#   (78, 1),
#   (86, 1),
#   (92, 1),
#   (184, 1),
#   (272, 1),
#   (331, 1),
#   (514, 1),
#   (554, 1),
#   (729, 1),
#   (818, 1),
#   (852, 1),
#   (971, 1),
#   (1026, 1),
#   (1068, 1),
#   (1200, 1),
#   (1201, 1),
#   (1202, 1),
#   (1203, 1),
#   (1204, 1),
#   (1205, 1),
#   (1206, 1),
#   (1207, 1),
#   (1208, 1),
#   (1209, 1),
#   (1210, 1)],
#  [(13, 2),
#   (25, 1),
#   (78, 1),
#   (80, 1),
#   (300, 1),
#   (396, 1),
#   (431, 1),
#   (504, 1),
#   (634, 1),
#   (684, 1),
#   (1085, 1),
#   (1211, 1),
#   (1212, 1),
#   (1213, 1)],
#  [(13, 2),
#   (37, 4),
#   (58, 1),
#   (420, 1),
#   (478, 1),
#   (503, 1),
#   (720, 2),
#   (1026, 1),
#   (1214, 1),
#   (1215, 1),
#   (1216, 1)],
#  [(22, 1),
#   (49, 1),
#   (73, 1),
#   (87, 1),
#   (128, 1),
#   (167, 1),
#   (169, 1),
#   (177, 1),
#   (254, 1),
#   (302, 1),
#   (461, 1),
#   (463, 1),
#   (510, 1),
#   (656, 1),
#   (689, 1),
#   (729, 1),
#   (827, 1),
#   (836, 1),
#   (1057, 1),
#   (1217, 1),
#   (1218, 1),
#   (1219, 1)],
#  [(7, 1),
#   (13, 1),
#   (73, 1),
#   (78, 2),
#   (86, 1),
#   (102, 1),
#   (168, 1),
#   (466, 1),
#   (559, 1),
#   (874, 1),
#   (1103, 1),
#   (1220, 1),
#   (1221, 1),
#   (1222, 1)],
#  [(11, 1),
#   (214, 1),
#   (498, 1),
#   (561, 1),
#   (565, 1),
#   (731, 1),
#   (778, 1),
#   (1152, 1),
#   (1223, 1),
#   (1224, 1)],
#  [(13, 1),
#   (39, 1),
#   (52, 1),
#   (78, 1),
#   (118, 1),
#   (157, 1),
#   (169, 1),
#   (333, 1),
#   (402, 2),
#   (444, 2),
#   (510, 1),
#   (607, 1),
#   (719, 1),
#   (739, 2),
#   (827, 2),
#   (836, 2),
#   (1026, 1),
#   (1078, 1),
#   (1198, 1),
#   (1225, 1),
#   (1226, 1),
#   (1227, 1)],
#  [(7, 1),
#   (60, 1),
#   (66, 2),
#   (138, 1),
#   (143, 1),
#   (235, 1),
#   (272, 1),
#   (1228, 1),
#   (1229, 1),
#   (1230, 1)],
#  [(7, 1),
#   (66, 2),
#   (73, 2),
#   (78, 1),
#   (104, 4),
#   (126, 2),
#   (162, 1),
#   (186, 1),
#   (242, 1),
#   (265, 1),
#   (289, 1),
#   (399, 1),
#   (403, 1),
#   (466, 1),
#   (469, 2),
#   (571, 1),
#   (575, 1),
#   (618, 1),
#   (763, 1),
#   (1153, 1),
#   (1177, 2),
#   (1231, 1),
#   (1232, 1),
#   (1233, 1),
#   (1234, 1),
#   (1235, 1),
#   (1236, 1)],
#  [(53, 1),
#   (72, 1),
#   (191, 1),
#   (266, 1),
#   (305, 1),
#   (331, 1),
#   (364, 1),
#   (368, 1),
#   (698, 1),
#   (750, 1)],
#  [(37, 6),
#   (44, 2),
#   (105, 2),
#   (144, 1),
#   (222, 1),
#   (232, 1),
#   (235, 1),
#   (318, 1),
#   (334, 1),
#   (403, 1),
#   (447, 1),
#   (468, 1),
#   (668, 1),
#   (754, 1),
#   (1237, 1),
#   (1238, 1),
#   (1239, 1),
#   (1240, 1),
#   (1241, 2),
#   (1242, 1),
#   (1243, 2)],
#  [(73, 2),
#   (128, 1),
#   (239, 1),
#   (266, 1),
#   (468, 1),
#   (510, 1),
#   (556, 1),
#   (728, 1),
#   (733, 1),
#   (946, 1),
#   (966, 1),
#   (1000, 1),
#   (1244, 1),
#   (1245, 1),
#   (1246, 1),
#   (1247, 1),
#   (1248, 1),
#   (1249, 1),
#   (1250, 1)],
#  [(39, 1),
#   (66, 2),
#   (78, 1),
#   (96, 1),
#   (109, 1),
#   (129, 1),
#   (203, 1),
#   (267, 1),
#   (305, 1),
#   (348, 1),
#   (391, 1),
#   (393, 1),
#   (394, 2),
#   (498, 1),
#   (552, 1),
#   (570, 1),
#   (602, 1),
#   (722, 1),
#   (820, 1),
#   (870, 1),
#   (1247, 1),
#   (1251, 1),
#   (1252, 1)],
#  [(266, 1),
#   (353, 1),
#   (451, 1),
#   (720, 1),
#   (800, 1),
#   (916, 1),
#   (1253, 1),
#   (1254, 1),
#   (1255, 2),
#   (1256, 1)],
#  [(17, 1),
#   (78, 1),
#   (79, 1),
#   (191, 1),
#   (358, 1),
#   (717, 1),
#   (882, 1),
#   (890, 1),
#   (952, 1),
#   (1159, 1),
#   (1257, 1),
#   (1258, 1),
#   (1259, 1),
#   (1260, 1),
#   (1261, 1),
#   (1262, 2),
#   (1263, 1),
#   (1264, 1)],
#  [(40, 2),
#   (73, 3),
#   (93, 1),
#   (126, 1),
#   (167, 1),
#   (186, 1),
#   (260, 1),
#   (266, 1),
#   (299, 1),
#   (308, 1),
#   (607, 1),
#   (698, 1),
#   (738, 1),
#   (1165, 2),
#   (1265, 2)],
#  [(19, 1),
#   (57, 1),
#   (60, 1),
#   (78, 2),
#   (86, 1),
#   (281, 1),
#   (459, 1),
#   (861, 2),
#   (1200, 1),
#   (1266, 1)],
#  [(13, 1),
#   (167, 1),
#   (236, 1),
#   (348, 1),
#   (350, 1),
#   (403, 1),
#   (559, 1),
#   (973, 1),
#   (1219, 1),
#   (1267, 3),
#   (1268, 1),
#   (1269, 1),
#   (1270, 1)],
#  [(19, 2),
#   (73, 1),
#   (78, 1),
#   (100, 1),
#   (128, 1),
#   (143, 1),
#   (167, 1),
#   (193, 1),
#   (364, 1),
#   (391, 2),
#   (514, 1),
#   (537, 1),
#   (1271, 1)],
#  [(52, 1),
#   (57, 1),
#   (109, 1),
#   (126, 2),
#   (129, 1),
#   (135, 1),
#   (203, 2),
#   (226, 1),
#   (358, 1),
#   (435, 1),
#   (436, 1),
#   (698, 1),
#   (720, 1),
#   (787, 2),
#   (894, 1),
#   (1256, 1)],
#  [(7, 1),
#   (17, 1),
#   (25, 1),
#   (60, 1),
#   (65, 1),
#   (66, 1),
#   (72, 1),
#   (78, 2),
#   (86, 1),
#   (111, 1),
#   (135, 1),
#   (142, 1),
#   (204, 1),
#   (256, 1),
#   (267, 1),
#   (272, 2),
#   (276, 1),
#   (299, 1),
#   (346, 1),
#   (403, 1),
#   (443, 1),
#   (514, 1),
#   (594, 1),
#   (730, 1),
#   (803, 2),
#   (813, 1),
#   (971, 2),
#   (1150, 1),
#   (1272, 2),
#   (1273, 1),
#   (1274, 1),
#   (1275, 1),
#   (1276, 1),
#   (1277, 1)],
#  [(55, 1),
#   (78, 1),
#   (90, 1),
#   (172, 1),
#   (186, 1),
#   (241, 1),
#   (278, 1),
#   (350, 1),
#   (446, 3),
#   (498, 1),
#   (717, 1),
#   (925, 1),
#   (1002, 1),
#   (1037, 1),
#   (1278, 1),
#   (1279, 1),
#   (1280, 1),
#   (1281, 1),
#   (1282, 1),
#   (1283, 1)],
#  [(13, 1),
#   (73, 1),
#   (78, 1),
#   (242, 1),
#   (1078, 1),
#   (1204, 1),
#   (1284, 1),
#   (1285, 1),
#   (1286, 1),
#   (1287, 1),
#   (1288, 1),
#   (1289, 1)],
#  [(118, 1),
#   (135, 1),
#   (222, 1),
#   (334, 1),
#   (537, 2),
#   (694, 1),
#   (876, 1),
#   (1290, 1)],
#  [(13, 4),
#   (55, 2),
#   (109, 1),
#   (278, 1),
#   (312, 1),
#   (332, 1),
#   (453, 1),
#   (462, 2),
#   (728, 2),
#   (741, 1),
#   (1291, 2)],
#  [(48, 1),
#   (73, 2),
#   (133, 1),
#   (135, 1),
#   (257, 1),
#   (277, 1),
#   (390, 1),
#   (559, 1),
#   (607, 1),
#   (803, 1),
#   (1292, 1),
#   (1293, 1),
#   (1294, 1),
#   (1295, 1),
#   (1296, 1),
#   (1297, 1)],
#  [(25, 2),
#   (232, 1),
#   (667, 1),
#   (670, 1),
#   (687, 1),
#   (720, 1),
#   (1213, 1),
#   (1298, 1),
#   (1299, 1),
#   (1300, 1),
#   (1301, 1),
#   (1302, 1)],
#  [(13, 2),
#   (74, 2),
#   (256, 1),
#   (414, 1),
#   (683, 1),
#   (758, 1),
#   (807, 2),
#   (1303, 1),
#   (1304, 1),
#   (1305, 2),
#   (1306, 1),
#   (1307, 1),
#   (1308, 1)],
#  [(7, 1),
#   (27, 1),
#   (78, 1),
#   (258, 2),
#   (338, 1),
#   (391, 1),
#   (466, 1),
#   (729, 1),
#   (1221, 1),
#   (1309, 1),
#   (1310, 2)],
#  [(82, 1), (256, 1), (338, 1), (629, 1), (1106, 2), (1311, 1), (1312, 1)],
#  [(13, 2),
#   (22, 1),
#   (53, 1),
#   (55, 1),
#   (154, 3),
#   (157, 1),
#   (222, 1),
#   (272, 1),
#   (336, 1),
#   (484, 1),
#   (498, 1),
#   (518, 2),
#   (551, 1),
#   (707, 1),
#   (845, 1),
#   (884, 1),
#   (1313, 1),
#   (1314, 1),
#   (1315, 1),
#   (1316, 2),
#   (1317, 1),
#   (1318, 1),
#   (1319, 1),
#   (1320, 1)],
#  [(231, 1),
#   (345, 1),
#   (402, 2),
#   (795, 1),
#   (875, 1),
#   (876, 1),
#   (1321, 1),
#   (1322, 1),
#   (1323, 1),
#   (1324, 1),
#   (1325, 1),
#   (1326, 1),
#   (1327, 2),
#   (1328, 1)],
#  [(37, 1),
#   (78, 1),
#   (235, 1),
#   (350, 1),
#   (436, 1),
#   (489, 1),
#   (511, 1),
#   (514, 1),
#   (703, 1),
#   (754, 1),
#   (1329, 1),
#   (1330, 1),
#   (1331, 1),
#   (1332, 1)],
#  [(13, 1),
#   (25, 1),
#   (66, 1),
#   (76, 2),
#   (403, 1),
#   (537, 1),
#   (756, 1),
#   (800, 1),
#   (817, 2),
#   (1333, 1),
#   (1334, 1),
#   (1335, 1)],
#  [(27, 1),
#   (86, 1),
#   (102, 1),
#   (133, 1),
#   (193, 1),
#   (257, 1),
#   (423, 1),
#   (444, 1),
#   (670, 1),
#   (803, 1),
#   (953, 1),
#   (1336, 1),
#   (1337, 1),
#   (1338, 1),
#   (1339, 1)],
#  [(55, 1),
#   (158, 1),
#   (231, 1),
#   (338, 2),
#   (423, 3),
#   (634, 1),
#   (894, 1),
#   (1340, 3)],
#  [(66, 1),
#   (78, 2),
#   (93, 1),
#   (117, 1),
#   (302, 1),
#   (358, 1),
#   (444, 1),
#   (461, 1),
#   (498, 1),
#   (698, 2),
#   (731, 1),
#   (1078, 1),
#   (1341, 1),
#   (1342, 1)],
#  [(141, 1), (162, 1), (687, 1), (941, 1)],
#  [(52, 1),
#   (186, 3),
#   (193, 2),
#   (256, 1),
#   (336, 1),
#   (346, 1),
#   (393, 1),
#   (576, 1),
#   (1343, 1)],
#  [(65, 1),
#   (114, 1),
#   (117, 1),
#   (272, 1),
#   (403, 3),
#   (631, 1),
#   (803, 1),
#   (1011, 1),
#   (1150, 1),
#   (1187, 1),
#   (1314, 1),
#   (1344, 1),
#   (1345, 1),
#   (1346, 1),
#   (1347, 1),
#   (1348, 1),
#   (1349, 1)],
#  [(19, 1),
#   (22, 1),
#   (37, 1),
#   (66, 1),
#   (73, 1),
#   (92, 1),
#   (95, 1),
#   (128, 1),
#   (141, 1),
#   (168, 1),
#   (424, 1),
#   (489, 1),
#   (1350, 1),
#   (1351, 1),
#   (1352, 1)],
#  [(13, 1),
#   (16, 1),
#   (25, 4),
#   (49, 1),
#   (52, 2),
#   (65, 1),
#   (75, 1),
#   (78, 1),
#   (92, 1),
#   (110, 1),
#   (111, 2),
#   (126, 1),
#   (154, 1),
#   (168, 2),
#   (457, 1),
#   (535, 1),
#   (605, 1),
#   (607, 2),
#   (608, 1),
#   (609, 1),
#   (610, 3),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1),
#   (618, 1),
#   (619, 1),
#   (620, 1),
#   (621, 1)],
#  [(13, 1),
#   (79, 1),
#   (130, 1),
#   (190, 2),
#   (248, 1),
#   (330, 1),
#   (537, 1),
#   (720, 1),
#   (863, 1),
#   (1142, 2),
#   (1353, 1),
#   (1354, 1),
#   (1355, 1)],
#  [(10, 1),
#   (83, 1),
#   (94, 2),
#   (99, 2),
#   (141, 1),
#   (382, 1),
#   (568, 1),
#   (667, 1),
#   (1356, 1)],
#  [(13, 1),
#   (16, 1),
#   (19, 1),
#   (37, 3),
#   (44, 1),
#   (48, 1),
#   (51, 1),
#   (66, 1),
#   (78, 1),
#   (91, 1),
#   (141, 1),
#   (235, 1),
#   (256, 1),
#   (291, 1),
#   (305, 2),
#   (351, 1),
#   (369, 1),
#   (420, 1),
#   (444, 1),
#   (465, 1),
#   (474, 1),
#   (475, 1),
#   (476, 2),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 1),
#   (482, 1),
#   (483, 1),
#   (484, 1)],
#  [(13, 2),
#   (19, 1),
#   (50, 1),
#   (137, 1),
#   (204, 2),
#   (268, 1),
#   (276, 2),
#   (281, 1),
#   (302, 1),
#   (368, 1),
#   (461, 1),
#   (738, 1),
#   (1068, 1),
#   (1357, 1),
#   (1358, 1),
#   (1359, 1)],
#  [(66, 1),
#   (92, 1),
#   (200, 1),
#   (346, 1),
#   (483, 1),
#   (846, 1),
#   (932, 1),
#   (1360, 1),
#   (1361, 1),
#   (1362, 1),
#   (1363, 1)],
#  [(171, 1),
#   (189, 1),
#   (231, 1),
#   (393, 1),
#   (978, 1),
#   (1027, 1),
#   (1265, 1),
#   (1364, 1),
#   (1365, 1),
#   (1366, 1),
#   (1367, 1),
#   (1368, 1),
#   (1369, 1)],
#  [(13, 1),
#   (37, 2),
#   (39, 1),
#   (66, 1),
#   (132, 1),
#   (162, 1),
#   (191, 1),
#   (364, 1),
#   (631, 2),
#   (713, 1),
#   (744, 1),
#   (1233, 1),
#   (1370, 1),
#   (1371, 1),
#   (1372, 1)],
#  [(13, 1),
#   (37, 3),
#   (73, 1),
#   (350, 1),
#   (403, 1),
#   (489, 1),
#   (602, 1),
#   (971, 1),
#   (1190, 1),
#   (1373, 1),
#   (1374, 1)],
#  [(13, 2),
#   (130, 1),
#   (241, 1),
#   (281, 1),
#   (367, 1),
#   (497, 2),
#   (504, 2),
#   (697, 1),
#   (876, 1),
#   (1106, 2),
#   (1322, 2),
#   (1375, 1),
#   (1376, 2),
#   (1377, 1),
#   (1378, 1),
#   (1379, 1)],
#  [(9, 2),
#   (13, 2),
#   (16, 1),
#   (78, 2),
#   (86, 1),
#   (92, 1),
#   (93, 1),
#   (95, 1),
#   (113, 1),
#   (180, 1),
#   (242, 1),
#   (265, 1),
#   (305, 1),
#   (307, 1),
#   (345, 1),
#   (449, 1),
#   (603, 1),
#   (617, 1),
#   (673, 1),
#   (793, 1),
#   (803, 1),
#   (804, 1),
#   (867, 2),
#   (1380, 1),
#   (1381, 1),
#   (1382, 1),
#   (1383, 1),
#   (1384, 1)],
#  [(9, 1), (13, 1), (164, 1), (242, 1), (272, 1), (1385, 1), (1386, 1)],
#  [(75, 2), (78, 1), (133, 1), (249, 1), (717, 1), (1069, 1), (1387, 1)],
#  [(55, 1), (232, 1), (374, 2), (462, 1), (679, 1), (1388, 1), (1389, 1)],
#  [(73, 1), (167, 1)],
#  [(73, 1),
#   (128, 1),
#   (168, 1),
#   (272, 1),
#   (312, 1),
#   (390, 1),
#   (756, 1),
#   (805, 1),
#   (914, 1),
#   (1034, 1),
#   (1068, 1),
#   (1339, 1),
#   (1390, 1),
#   (1391, 1),
#   (1392, 1),
#   (1393, 1),
#   (1394, 1),
#   (1395, 1)],
#  [(13, 3),
#   (52, 1),
#   (81, 1),
#   (87, 1),
#   (109, 1),
#   (348, 1),
#   (420, 2),
#   (489, 1),
#   (551, 1),
#   (554, 1),
#   (720, 1),
#   (728, 2),
#   (733, 1),
#   (750, 1),
#   (1050, 1),
#   (1396, 1),
#   (1397, 1),
#   (1398, 1),
#   (1399, 1),
#   (1400, 1),
#   (1401, 1),
#   (1402, 3),
#   (1403, 1)],
#  [(9, 1),
#   (58, 1),
#   (99, 1),
#   (147, 1),
#   (247, 1),
#   (272, 1),
#   (336, 2),
#   (405, 2),
#   (568, 1),
#   (697, 1),
#   (753, 1),
#   (762, 1),
#   (830, 1),
#   (883, 1),
#   (1109, 1),
#   (1404, 1),
#   (1405, 1),
#   (1406, 1),
#   (1407, 1),
#   (1408, 1),
#   (1409, 1),
#   (1410, 1),
#   (1411, 1),
#   (1412, 1),
#   (1413, 1),
#   (1414, 1)],
#  [(23, 1),
#   (60, 1),
#   (66, 2),
#   (143, 1),
#   (387, 1),
#   (423, 2),
#   (486, 1),
#   (1068, 1)],
#  [(79, 1),
#   (111, 1),
#   (130, 1),
#   (132, 1),
#   (312, 1),
#   (497, 1),
#   (504, 1),
#   (576, 1),
#   (1042, 1),
#   (1053, 1),
#   (1415, 1),
#   (1416, 1)],
#  [(13, 1), (694, 1), (859, 1)],
#  [(25, 1),
#   (111, 2),
#   (407, 1),
#   (511, 1),
#   (1277, 1),
#   (1417, 1),
#   (1418, 1),
#   (1419, 1)],
#  [(368, 1), (602, 1), (1280, 1), (1420, 1), (1421, 2), (1422, 1), (1423, 1)],
#  [(55, 1),
#   (58, 1),
#   (75, 3),
#   (78, 1),
#   (99, 2),
#   (135, 2),
#   (320, 1),
#   (360, 1),
#   (363, 7),
#   (374, 1),
#   (679, 2),
#   (1015, 1),
#   (1190, 1),
#   (1424, 1),
#   (1425, 1),
#   (1426, 2),
#   (1427, 1),
#   (1428, 1),
#   (1429, 1),
#   (1430, 1),
#   (1431, 1),
#   (1432, 1),
#   (1433, 1)],
#  [(73, 1),
#   (93, 1),
#   (102, 1),
#   (222, 1),
#   (256, 1),
#   (261, 1),
#   (727, 1),
#   (729, 1),
#   (1107, 1),
#   (1434, 1),
#   (1435, 1)],
#  [(178, 1),
#   (187, 2),
#   (189, 1),
#   (200, 6),
#   (332, 1),
#   (402, 1),
#   (415, 1),
#   (479, 1),
#   (492, 1),
#   (670, 1),
#   (736, 2),
#   (835, 1),
#   (966, 2),
#   (1436, 4),
#   (1437, 1),
#   (1438, 1),
#   (1439, 2),
#   (1440, 1),
#   (1441, 1),
#   (1442, 3)],
#  [(13, 1),
#   (17, 1),
#   (19, 1),
#   (73, 2),
#   (78, 2),
#   (86, 1),
#   (92, 1),
#   (95, 1),
#   (104, 1),
#   (129, 1),
#   (142, 1),
#   (232, 1),
#   (261, 1),
#   (267, 1),
#   (350, 1),
#   (358, 1),
#   (390, 1),
#   (469, 1),
#   (602, 1),
#   (634, 1),
#   (670, 1),
#   (1177, 4),
#   (1363, 1),
#   (1428, 1),
#   (1443, 1),
#   (1444, 1),
#   (1445, 1),
#   (1446, 1),
#   (1447, 1)],
#  [(13, 1),
#   (92, 1),
#   (95, 1),
#   (126, 1),
#   (162, 1),
#   (267, 1),
#   (312, 1),
#   (402, 1),
#   (671, 1),
#   (941, 2),
#   (1448, 1),
#   (1449, 1)],
#  [(66, 1),
#   (91, 2),
#   (266, 1),
#   (369, 1),
#   (407, 1),
#   (720, 1),
#   (946, 2),
#   (1450, 1),
#   (1451, 1),
#   (1452, 1),
#   (1453, 1),
#   (1454, 1),
#   (1455, 1)],
#  [(25, 1),
#   (60, 1),
#   (73, 2),
#   (77, 1),
#   (83, 1),
#   (126, 1),
#   (151, 1),
#   (402, 1),
#   (607, 1),
#   (657, 1),
#   (667, 1),
#   (1447, 1),
#   (1456, 1),
#   (1457, 2),
#   (1458, 1)],
#  [(13, 3),
#   (20, 1),
#   (22, 1),
#   (154, 1),
#   (172, 1),
#   (222, 1),
#   (364, 1),
#   (652, 1),
#   (692, 1),
#   (1084, 1),
#   (1150, 1),
#   (1221, 1),
#   (1459, 1),
#   (1460, 1),
#   (1461, 1),
#   (1462, 1),
#   (1463, 1)],
#  [(78, 1),
#   (94, 1),
#   (132, 1),
#   (190, 1),
#   (257, 1),
#   (258, 3),
#   (360, 1),
#   (391, 1),
#   (449, 1),
#   (1249, 1),
#   (1339, 1),
#   (1464, 1),
#   (1465, 1),
#   (1466, 1),
#   (1467, 1)],
#  [(13, 1),
#   (25, 1),
#   (78, 1),
#   (158, 1),
#   (254, 1),
#   (302, 1),
#   (360, 1),
#   (461, 1),
#   (594, 1),
#   (603, 1),
#   (698, 1),
#   (1468, 1),
#   (1469, 1),
#   (1470, 1)],
#  [(5, 1),
#   (19, 1),
#   (23, 3),
#   (55, 1),
#   (73, 2),
#   (92, 1),
#   (171, 1),
#   (320, 1),
#   (364, 1),
#   (462, 1),
#   (745, 2),
#   (756, 1),
#   (1107, 1),
#   (1110, 1),
#   (1471, 1),
#   (1472, 1)],
#  [(12, 1),
#   (37, 1),
#   (39, 1),
#   (66, 1),
#   (72, 1),
#   (92, 1),
#   (104, 1),
#   (128, 1),
#   (222, 1),
#   (232, 1),
#   (291, 1),
#   (350, 1),
#   (353, 1),
#   (391, 1),
#   (448, 1),
#   (476, 1),
#   (478, 1),
#   (570, 1),
#   (825, 1),
#   (1342, 1),
#   (1473, 1),
#   (1474, 1)],
#  [(9, 3),
#   (51, 2),
#   (86, 1),
#   (89, 1),
#   (102, 2),
#   (136, 1),
#   (141, 1),
#   (156, 1),
#   (198, 1),
#   (235, 1),
#   (291, 1),
#   (365, 2),
#   (370, 1),
#   (403, 1),
#   (483, 1),
#   (489, 1),
#   (675, 1),
#   (821, 1),
#   (836, 1),
#   (926, 2),
#   (954, 1),
#   (1230, 1),
#   (1475, 1),
#   (1476, 1),
#   (1477, 1),
#   (1478, 1),
#   (1479, 1)],
#  [(651, 2),
#   (1480, 1),
#   (1481, 1),
#   (1482, 1),
#   (1483, 1),
#   (1484, 1),
#   (1485, 2),
#   (1486, 1),
#   (1487, 1)],
#  [(72, 1),
#   (143, 1),
#   (167, 1),
#   (285, 1),
#   (305, 1),
#   (333, 1),
#   (348, 1),
#   (424, 1),
#   (478, 1),
#   (739, 1),
#   (1488, 1)],
#  [(16, 1),
#   (65, 1),
#   (75, 1),
#   (78, 1),
#   (166, 1),
#   (489, 1),
#   (619, 1),
#   (1283, 1),
#   (1489, 1),
#   (1490, 1),
#   (1491, 1),
#   (1492, 1),
#   (1493, 1)],
#  [(7, 1),
#   (13, 1),
#   (19, 1),
#   (91, 1),
#   (92, 2),
#   (130, 1),
#   (135, 1),
#   (288, 1),
#   (300, 2),
#   (305, 1),
#   (344, 1),
#   (396, 1),
#   (492, 1),
#   (537, 1),
#   (677, 1),
#   (748, 2),
#   (833, 1),
#   (862, 1),
#   (874, 1),
#   (919, 1),
#   (974, 3),
#   (1194, 1),
#   (1232, 1),
#   (1494, 1),
#   (1495, 1),
#   (1496, 1),
#   (1497, 1),
#   (1498, 2),
#   (1499, 1)],
#  [(0, 1),
#   (13, 1),
#   (25, 1),
#   (69, 2),
#   (111, 2),
#   (157, 1),
#   (391, 1),
#   (589, 1),
#   (1088, 1),
#   (1500, 1)],
#  [(2, 1),
#   (3, 2),
#   (13, 3),
#   (16, 1),
#   (25, 2),
#   (38, 1),
#   (51, 3),
#   (111, 1),
#   (144, 1),
#   (147, 1),
#   (232, 1),
#   (489, 1),
#   (952, 1),
#   (974, 1),
#   (986, 1),
#   (1004, 1),
#   (1006, 1),
#   (1501, 1),
#   (1502, 1)],
#  [(19, 1),
#   (35, 1),
#   (37, 4),
#   (100, 1),
#   (164, 1),
#   (238, 1),
#   (300, 1),
#   (336, 1),
#   (368, 1),
#   (420, 1),
#   (443, 1),
#   (486, 1),
#   (532, 1),
#   (634, 1),
#   (698, 1),
#   (714, 1),
#   (864, 1),
#   (884, 1),
#   (916, 1),
#   (957, 1),
#   (972, 1),
#   (1053, 1),
#   (1187, 1),
#   (1234, 1),
#   (1497, 1),
#   (1503, 1),
#   (1504, 1),
#   (1505, 1),
#   (1506, 1)],
#  [(16, 2),
#   (36, 1),
#   (60, 1),
#   (91, 1),
#   (92, 2),
#   (102, 1),
#   (106, 1),
#   (305, 1),
#   (391, 1),
#   (945, 1),
#   (991, 1),
#   (1198, 1),
# ...
#   (1680, 1),
#   (2422, 1),
#   (2984, 1),
#   (3049, 1)],
#  [(79, 1),
#   (93, 1),
#   (147, 1),
#   (302, 3),
#   (387, 1),
#   (403, 1),
#   (468, 1),
#   (634, 1),
#   (666, 2),
#   (670, 1),
#   (946, 1),
#   (1688, 1),
#   (1938, 1),
#   (2977, 1),
#   (3188, 1),
#   (3189, 1)],
#  [(25, 1),
#   (54, 1),
#   (57, 1),
#   (93, 1),
#   (111, 1),
#   (171, 1),
#   (394, 1),
#   (449, 1),
#   (470, 1),
#   (896, 1),
#   (1107, 1),
#   (1524, 1),
#   (1580, 1),
#   (1662, 1),
#   (2200, 1),
#   (2358, 1),
#   (3190, 1),
#   (3191, 1)],
#  [(7, 1),
#   (66, 1),
#   (78, 1),
#   (91, 2),
#   (93, 1),
#   (128, 1),
#   (141, 5),
#   (147, 1),
#   (350, 1),
#   (390, 1),
#   (423, 4),
#   (702, 1),
#   (1037, 3),
#   (1225, 1),
#   (1329, 6),
#   (1332, 1),
#   (1484, 1),
#   (2417, 1),
#   (2497, 1),
#   (3192, 1),
#   (3193, 3),
#   (3194, 1)],
#  [(13, 1),
#   (57, 1),
#   (73, 1),
#   (391, 1),
#   (486, 1),
#   (491, 1),
#   (898, 1),
#   (1533, 1),
#   (1695, 1),
#   (3145, 1)],
#  [(24, 1),
#   (73, 1),
#   (78, 1),
#   (158, 1),
#   (164, 1),
#   (203, 1),
#   (390, 1),
#   (492, 1),
#   (580, 1),
#   (694, 1),
#   (1201, 1),
#   (1220, 1),
#   (1340, 2),
#   (3195, 1)],
#  [(73, 1), (256, 1), (305, 1), (729, 2), (777, 1), (3196, 1)],
#  [(16, 1),
#   (93, 1),
#   (189, 1),
#   (299, 1),
#   (468, 1),
#   (553, 1),
#   (897, 1),
#   (1695, 1),
#   (3197, 1),
#   (3198, 1)],
#  [(5, 1),
#   (16, 1),
#   (98, 1),
#   (132, 1),
#   (178, 1),
#   (189, 1),
#   (489, 1),
#   (790, 1),
#   (1190, 1),
#   (1493, 1),
#   (1524, 1),
#   (1695, 1),
#   (1877, 1),
#   (2529, 1),
#   (3199, 1),
#   (3200, 1)],
#  [(143, 2),
#   (189, 2),
#   (193, 1),
#   (300, 1),
#   (391, 1),
#   (538, 1),
#   (670, 1),
#   (804, 1),
#   (971, 1),
#   (1068, 1),
#   (1107, 1),
#   (1176, 1),
#   (1675, 3),
#   (2030, 1),
#   (2068, 1),
#   (2725, 1)],
#  [(1, 1),
#   (22, 1),
#   (60, 1),
#   (66, 1),
#   (184, 1),
#   (299, 1),
#   (949, 1),
#   (1225, 1),
#   (1383, 1),
#   (2135, 2),
#   (3201, 1),
#   (3202, 1)],
#  [(13, 1),
#   (55, 1),
#   (91, 1),
#   (126, 2),
#   (127, 1),
#   (132, 1),
#   (137, 1),
#   (266, 1),
#   (364, 1),
#   (462, 1),
#   (555, 1),
#   (605, 1),
#   (697, 1),
#   (1631, 1),
#   (1938, 1),
#   (2632, 1),
#   (3203, 1),
#   (3204, 2)],
#  [(13, 2),
#   (109, 2),
#   (169, 1),
#   (186, 1),
#   (222, 1),
#   (265, 1),
#   (391, 1),
#   (393, 1),
#   (435, 3),
#   (698, 1),
#   (972, 1),
#   (2410, 1),
#   (2840, 1),
#   (3205, 1),
#   (3206, 1),
#   (3207, 1),
#   (3208, 1)],
#  [(16, 1), (73, 1), (109, 1), (239, 1), (499, 2), (3209, 1), (3210, 1)],
#  [(56, 1),
#   (58, 1),
#   (78, 3),
#   (92, 1),
#   (95, 1),
#   (200, 1),
#   (211, 1),
#   (258, 2),
#   (278, 1),
#   (345, 1),
#   (403, 1),
#   (750, 1),
#   (939, 1),
#   (1364, 1),
#   (1417, 1),
#   (2209, 1),
#   (2299, 1),
#   (2683, 1),
#   (3211, 1),
#   (3212, 1)],
#  [(19, 1), (37, 4), (129, 1), (479, 2), (1505, 1), (2562, 1), (2888, 1)],
#  [(11, 1),
#   (15, 1),
#   (57, 1),
#   (109, 1),
#   (269, 1),
#   (278, 1),
#   (364, 1),
#   (393, 1),
#   (537, 3),
#   (744, 2),
#   (749, 3),
#   (750, 1),
#   (783, 1),
#   (801, 1),
#   (871, 1),
#   (874, 1),
#   (1793, 1),
#   (2680, 1),
#   (2942, 1),
#   (3213, 1)],
#  [(0, 1),
#   (13, 5),
#   (25, 1),
#   (27, 1),
#   (55, 1),
#   (299, 1),
#   (514, 1),
#   (1015, 1),
#   (1045, 1),
#   (1046, 1),
#   (1047, 1),
#   (1048, 1),
#   (1049, 1)],
#  [(156, 2),
#   (336, 1),
#   (558, 1),
#   (581, 2),
#   (654, 1),
#   (670, 1),
#   (722, 1),
#   (1364, 1),
#   (2452, 1),
#   (3214, 1),
#   (3215, 1)],
#  [(49, 2),
#   (66, 3),
#   (73, 1),
#   (96, 1),
#   (129, 1),
#   (136, 1),
#   (177, 1),
#   (399, 1),
#   (467, 1),
#   (679, 1),
#   (911, 1),
#   (1197, 1),
#   (2686, 1),
#   (3216, 1),
#   (3217, 1)],
#  [(25, 2),
#   (239, 1),
#   (272, 1),
#   (291, 2),
#   (299, 1),
#   (381, 2),
#   (489, 1),
#   (510, 2),
#   (653, 1),
#   (659, 2),
#   (698, 1),
#   (800, 2),
#   (846, 1),
#   (972, 1),
#   (1004, 1),
#   (1037, 1),
#   (1214, 1),
#   (1492, 1),
#   (1561, 1),
#   (1741, 1),
#   (1799, 2),
#   (1973, 1),
#   (3218, 1),
#   (3219, 1),
#   (3220, 1),
#   (3221, 1),
#   (3222, 1),
#   (3223, 1),
#   (3224, 1),
#   (3225, 1),
#   (3226, 1),
#   (3227, 1),
#   (3228, 1),
#   (3229, 1),
#   (3230, 1),
#   (3231, 1),
#   (3232, 1)],
#  [(4, 2),
#   (13, 3),
#   (36, 2),
#   (52, 2),
#   (241, 1),
#   (320, 1),
#   (391, 3),
#   (573, 1),
#   (672, 2),
#   (742, 1),
#   (1030, 1),
#   (1210, 1),
#   (1312, 2),
#   (2007, 1),
#   (3233, 1),
#   (3234, 1),
#   (3235, 2)],
#  [(131, 1),
#   (291, 1),
#   (338, 1),
#   (391, 1),
#   (464, 1),
#   (607, 1),
#   (697, 1),
#   (846, 1),
#   (1501, 1),
#   (3236, 1)],
#  [(16, 1),
#   (52, 1),
#   (73, 1),
#   (141, 1),
#   (557, 1),
#   (662, 1),
#   (756, 1),
#   (1190, 1),
#   (1311, 1)],
#  [(7, 2),
#   (73, 1),
#   (92, 1),
#   (156, 3),
#   (168, 1),
#   (228, 1),
#   (497, 1),
#   (580, 2),
#   (965, 1),
#   (1413, 1),
#   (1917, 1),
#   (2998, 1)],
#  [(91, 1),
#   (92, 1),
#   (143, 1),
#   (162, 1),
#   (242, 1),
#   (272, 1),
#   (305, 1),
#   (332, 1),
#   (350, 1),
#   (359, 1),
#   (479, 1),
#   (537, 2),
#   (698, 1),
#   (1322, 1),
#   (1915, 1),
#   (1944, 1),
#   (2094, 1),
#   (2529, 1),
#   (3081, 1),
#   (3100, 1),
#   (3237, 1),
#   (3238, 1),
#   (3239, 1),
#   (3240, 1),
#   (3241, 1),
#   (3242, 1)],
#  [(25, 2),
#   (40, 1),
#   (49, 1),
#   (52, 1),
#   (55, 1),
#   (66, 1),
#   (73, 1),
#   (79, 1),
#   (80, 1),
#   (111, 1),
#   (136, 1),
#   (239, 3),
#   (346, 1),
#   (353, 1),
#   (467, 1),
#   (489, 1),
#   (499, 3),
#   (578, 1),
#   (584, 1),
#   (616, 1),
#   (757, 1),
#   (1081, 1),
#   (1399, 1),
#   (1894, 1),
#   (2417, 2),
#   (2750, 1),
#   (3243, 1),
#   (3244, 1),
#   (3245, 2),
#   (3246, 1),
#   (3247, 1),
#   (3248, 1)],
#  [(13, 2),
#   (60, 1),
#   (111, 1),
#   (128, 1),
#   (200, 1),
#   (403, 1),
#   (560, 1),
#   (708, 1),
#   (972, 1),
#   (1265, 1),
#   (1424, 1),
#   (2090, 1),
#   (2824, 1),
#   (3249, 1),
#   (3250, 1)],
#  [(37, 1), (93, 1), (256, 1), (403, 1), (568, 1), (602, 1)],
#  [(66, 1),
#   (87, 1),
#   (111, 1),
#   (130, 1),
#   (413, 1),
#   (489, 1),
#   (1220, 1),
#   (1675, 1),
#   (3010, 1)],
#  [(78, 1),
#   (166, 1),
#   (193, 1),
#   (405, 1),
#   (504, 3),
#   (695, 1),
#   (1477, 1),
#   (1657, 1),
#   (2849, 1),
#   (3251, 1),
#   (3252, 1),
#   (3253, 1)],
#  [(13, 1),
#   (40, 1),
#   (73, 2),
#   (78, 1),
#   (111, 1),
#   (186, 2),
#   (222, 1),
#   (242, 1),
#   (300, 1),
#   (350, 1),
#   (795, 1),
#   (875, 1),
#   (1135, 1),
#   (1311, 1),
#   (1384, 1),
#   (3254, 1),
#   (3255, 1),
#   (3256, 1)],
#  [(13, 2),
#   (19, 1),
#   (39, 1),
#   (66, 4),
#   (78, 1),
#   (141, 4),
#   (147, 1),
#   (260, 2),
#   (337, 2),
#   (355, 1),
#   (358, 1),
#   (466, 1),
#   (467, 1),
#   (514, 1),
#   (572, 1),
#   (803, 1),
#   (1037, 1),
#   (1875, 3),
#   (3257, 1),
#   (3258, 1)],
#  [(13, 1),
#   (91, 1),
#   (131, 1),
#   (242, 1),
#   (449, 1),
#   (459, 1),
#   (502, 1),
#   (554, 1),
#   (741, 1),
#   (1219, 1),
#   (1363, 1),
#   (1827, 1),
#   (3259, 2),
#   (3260, 1)],
#  [(25, 1), (75, 1), (193, 1), (717, 1), (832, 1), (1458, 1)],
#  [(13, 1),
#   (25, 3),
#   (48, 1),
#   (58, 1),
#   (75, 3),
#   (127, 1),
#   (132, 1),
#   (166, 2),
#   (172, 1),
#   (272, 1),
#   (300, 3),
#   (435, 2),
#   (621, 1),
#   (1213, 1),
#   (1591, 2),
#   (1856, 1)],
#  [(52, 1),
#   (203, 1),
#   (232, 1),
#   (239, 1),
#   (344, 1),
#   (499, 1),
#   (557, 1),
#   (733, 1),
#   (857, 1),
#   (874, 1),
#   (1068, 1),
#   (1835, 1),
#   (2498, 1),
#   (3261, 1),
#   (3262, 1),
#   (3263, 1),
#   (3264, 1)],
#  [(47, 1),
#   (113, 1),
#   (141, 1),
#   (236, 1),
#   (256, 1),
#   (478, 1),
#   (568, 1),
#   (3265, 1),
#   (3266, 1)],
#  [(13, 1),
#   (66, 1),
#   (118, 1),
#   (291, 1),
#   (344, 2),
#   (807, 1),
#   (1055, 1),
#   (1199, 2),
#   (1838, 1),
#   (3267, 1)],
#  [(13, 1),
#   (25, 1),
#   (78, 1),
#   (186, 1),
#   (407, 2),
#   (602, 1),
#   (1110, 1),
#   (3268, 3)],
#  [(2, 1),
#   (3, 1),
#   (5, 1),
#   (7, 1),
#   (13, 1),
#   (48, 1),
#   (55, 1),
#   (73, 1),
#   (78, 1),
#   (86, 1),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (106, 1),
#   (128, 1),
#   (232, 1),
#   (272, 1),
#   (556, 1),
#   (582, 1),
#   (601, 2),
#   (602, 1),
#   (616, 1),
#   (827, 1),
#   (918, 1),
#   (1264, 1),
#   (1750, 1),
#   (1884, 1),
#   (3269, 1),
#   (3270, 1),
#   (3271, 1)],
#  [(13, 1),
#   (19, 1),
#   (25, 3),
#   (31, 1),
#   (66, 1),
#   (73, 1),
#   (74, 3),
#   (86, 1),
#   (100, 1),
#   (102, 1),
#   (186, 1),
#   (222, 1),
#   (260, 1),
#   (407, 1),
#   (499, 1),
#   (510, 1),
#   (553, 1),
#   (613, 1),
#   (821, 1),
#   (861, 1),
#   (896, 1),
#   (916, 1),
#   (3272, 1),
#   (3273, 1),
#   (3274, 1),
#   (3275, 1),
#   (3276, 2)],
#  [(109, 1),
#   (190, 1),
#   (560, 1),
#   (689, 1),
#   (788, 2),
#   (1000, 2),
#   (1005, 1),
#   (1184, 1),
#   (1631, 1),
#   (1760, 2),
#   (2743, 1),
#   (3277, 1),
#   (3278, 1)],
#  [(7, 1),
#   (9, 1),
#   (94, 2),
#   (109, 1),
#   (126, 1),
#   (147, 1),
#   (391, 1),
#   (403, 1),
#   (423, 3),
#   (428, 1),
#   (514, 1),
#   (559, 1),
#   (804, 1),
#   (1173, 1),
#   (1190, 1),
#   (1221, 1),
#   (2043, 1),
#   (2192, 1),
#   (2349, 1),
#   (3279, 1)],
#  [(13, 1), (52, 1), (132, 1), (720, 1), (3280, 1), (3281, 1), (3282, 1)],
#  [(66, 1),
#   (73, 2),
#   (78, 1),
#   (236, 1),
#   (946, 2),
#   (1229, 1),
#   (1329, 1),
#   (1360, 1),
#   (1361, 1),
#   (2462, 1),
#   (3243, 1),
#   (3283, 1),
#   (3284, 1),
#   (3285, 1),
#   (3286, 1),
#   (3287, 1)],
#  [(5, 1),
#   (73, 1),
#   (102, 1),
#   (168, 1),
#   (510, 1),
#   (538, 1),
#   (559, 2),
#   (729, 1),
#   (1139, 1),
#   (1311, 1),
#   (1662, 1),
#   (3288, 1),
#   (3289, 1)],
#  [(16, 1),
#   (78, 1),
#   (128, 1),
#   (203, 3),
#   (383, 1),
#   (589, 1),
#   (803, 1),
#   (883, 1),
#   (974, 1),
#   (1106, 2),
#   (1813, 1),
#   (1858, 1),
#   (3005, 1),
#   (3009, 1),
#   (3290, 1),
#   (3291, 1)],
#  [(22, 1),
#   (25, 2),
#   (186, 1),
#   (272, 1),
#   (311, 1),
#   (436, 1),
#   (859, 1),
#   (918, 1),
#   (1029, 1),
#   (3292, 1),
#   (3293, 1),
#   (3294, 1)],
#  [(78, 1),
#   (99, 1),
#   (132, 1),
#   (193, 1),
#   (346, 1),
#   (483, 1),
#   (1630, 1),
#   (2256, 1),
#   (3295, 1)],
#  [(55, 1),
#   (167, 1),
#   (272, 1),
#   (312, 1),
#   (321, 1),
#   (394, 1),
#   (551, 1),
#   (750, 2),
#   (1197, 2),
#   (1198, 1),
#   (1395, 1),
#   (1516, 1),
#   (2140, 2),
#   (2562, 2),
#   (2686, 1),
#   (3296, 1)],
#  [(16, 1),
#   (44, 1),
#   (51, 1),
#   (55, 1),
#   (73, 1),
#   (92, 1),
#   (289, 1),
#   (299, 1),
#   (607, 1),
#   (728, 1),
#   (860, 1),
#   (2653, 1)],
#  [(13, 1),
#   (22, 1),
#   (25, 2),
#   (27, 1),
#   (109, 1),
#   (242, 1),
#   (267, 1),
#   (504, 1),
#   (598, 1),
#   (631, 1),
#   (634, 1),
#   (709, 1),
#   (795, 2),
#   (1084, 1),
#   (1213, 1),
#   (1256, 1),
#   (1322, 1),
#   (2748, 1),
#   (2783, 2),
#   (2784, 1),
#   (2785, 1)],
#  [(13, 1),
#   (73, 2),
#   (86, 1),
#   (111, 1),
#   (235, 1),
#   (256, 1),
#   (272, 1),
#   (350, 1),
#   (360, 1),
#   (734, 1),
#   (1017, 1),
#   (2231, 1),
#   (2434, 1),
#   (2662, 1),
#   (3167, 1),
#   (3297, 1),
#   (3298, 1)],
#  [(13, 1), (78, 1), (305, 1), (1179, 1), (3299, 1)],
#  [(23, 1),
#   (25, 4),
#   (102, 1),
#   (128, 1),
#   (187, 1),
#   (272, 1),
#   (370, 1),
#   (492, 1),
#   (507, 1),
#   (1038, 1),
#   (1505, 1),
#   (1632, 2),
#   (2183, 1),
#   (2198, 1),
#   (3300, 1),
#   (3301, 1)],
#  [(52, 1),
#   (55, 1),
#   (58, 1),
#   (60, 1),
#   (78, 1),
#   (117, 2),
#   (128, 1),
#   (130, 1),
#   (284, 2),
#   (302, 1),
#   (350, 1),
#   (387, 1),
#   (393, 1),
#   (461, 1),
#   (462, 1),
#   (463, 1),
#   (775, 1),
#   (777, 1),
#   (803, 1),
#   (1107, 2),
#   (1220, 1),
#   (1245, 1),
#   (1435, 1),
#   (1640, 1),
#   (1675, 2),
#   (1702, 1),
#   (1703, 1),
#   (1704, 1),
#   (1705, 1),
#   (1706, 1)],
#  [(16, 1),
#   (73, 1),
#   (87, 1),
#   (358, 1),
#   (668, 2),
#   (1068, 1),
#   (2020, 1),
#   (2341, 1),
#   (2520, 2),
#   (3132, 1),
#   (3302, 1)],
#  [(25, 1),
#   (48, 1),
#   (52, 1),
#   (142, 1),
#   (162, 1),
#   (172, 2),
#   (368, 1),
#   (424, 1),
#   (552, 1),
#   (874, 1),
#   (974, 1),
#   (1452, 1),
#   (1465, 1),
#   (2043, 2),
#   (2046, 2),
#   (3303, 1),
#   (3304, 1)],
#  [(7, 1),
#   (73, 1),
#   (158, 2),
#   (443, 1),
#   (800, 1),
#   (1630, 2),
#   (2529, 1),
#   (3305, 1)],
#  [(12, 1),
#   (22, 2),
#   (73, 1),
#   (133, 1),
#   (154, 1),
#   (167, 1),
#   (231, 1),
#   (268, 1),
#   (281, 1),
#   (302, 1),
#   (305, 1),
#   (336, 1),
#   (393, 1),
#   (461, 1),
#   (489, 1),
#   (576, 1),
#   (584, 1),
#   (670, 1),
#   (787, 1),
#   (819, 1),
#   (836, 1),
#   (863, 1),
#   (866, 1),
#   (909, 1),
#   (942, 1),
#   (1456, 1),
#   (1640, 2),
#   (1741, 1),
#   (3306, 1),
#   (3307, 1),
#   (3308, 1),
#   (3309, 1)],
#  [(10, 1),
#   (25, 1),
#   (86, 1),
#   (150, 1),
#   (156, 1),
#   (305, 1),
#   (338, 1),
#   (670, 1),
#   (863, 1),
#   (939, 1),
#   (1170, 1),
#   (1402, 1),
#   (1464, 1),
#   (1494, 1),
#   (3310, 1)],
#  [(48, 1),
#   (66, 1),
#   (78, 1),
#   (111, 1),
#   (128, 1),
#   (139, 1),
#   (312, 3),
#   (403, 1),
#   (559, 1),
#   (590, 1),
#   (729, 1),
#   (777, 1),
#   (812, 1),
#   (836, 1),
#   (928, 1),
#   (1068, 1),
#   (1078, 1),
#   (1229, 2),
#   (2330, 1),
#   (2723, 1),
#   (3311, 1),
#   (3312, 1)],
#  [(13, 1),
#   (37, 1),
#   (107, 1),
#   (129, 1),
#   (436, 1),
#   (756, 1),
#   (1264, 1),
#   (1280, 1),
#   (3313, 1)],
#  [(52, 1),
#   (65, 1),
#   (92, 1),
#   (200, 1),
#   (222, 1),
#   (403, 2),
#   (463, 1),
#   (926, 3),
#   (935, 1),
#   (1173, 1),
#   (1529, 1),
#   (3314, 1)],
#  [(13, 1),
#   (25, 2),
#   (65, 1),
#   (73, 1),
#   (226, 1),
#   (325, 1),
#   (403, 1),
#   (817, 3),
#   (916, 1),
#   (1274, 3),
#   (1446, 1),
#   (1594, 1),
#   (1640, 1),
#   (2157, 1),
#   (2792, 1),
#   (3009, 1),
#   (3315, 1),
#   (3316, 1),
#   (3317, 1),
#   (3318, 1)],
#  [(19, 1),
#   (53, 1),
#   (111, 1),
#   (232, 1),
#   (281, 1),
#   (499, 1),
#   (870, 1),
#   (1314, 2),
#   (2183, 1),
#   (2339, 1),
#   (3319, 1),
#   (3320, 1)],
#  [(135, 1),
#   (423, 1),
#   (559, 1),
#   (561, 1),
#   (822, 1),
#   (953, 1),
#   (1174, 1),
#   (1630, 1),
#   (1714, 1)],
#  [(13, 4), (132, 1), (1236, 1), (1449, 1), (2778, 1)],
#  [(13, 1),
#   (19, 1),
#   (40, 1),
#   (350, 1),
#   (376, 1),
#   (437, 1),
#   (495, 1),
#   (532, 1),
#   (542, 1),
#   (560, 1),
#   (874, 1),
#   (2045, 1),
#   (3321, 1)],
#  [(74, 1),
#   (111, 1),
#   (336, 1),
#   (353, 1),
#   (722, 1),
#   (1040, 1),
#   (1103, 1),
#   (1187, 1),
#   (1311, 1),
#   (1675, 1),
#   (2893, 1),
#   (3126, 1)],
#  [(13, 2),
#   (19, 1),
#   (28, 1),
#   (48, 1),
#   (60, 1),
#   (80, 2),
#   (86, 1),
#   (102, 1),
#   (106, 1),
#   (111, 1),
#   (128, 1),
#   (174, 1),
#   (265, 1),
#   (351, 1),
#   (359, 1),
#   (382, 1),
#   (413, 2),
#   (448, 1),
#   (514, 1),
#   (634, 1),
#   (708, 1),
#   (742, 1),
#   (863, 1),
#   (891, 1),
#   (945, 1),
#   (1252, 3),
#   (1636, 1),
#   (2022, 1),
#   (3322, 1),
#   (3323, 1),
#   (3324, 2),
#   (3325, 1),
#   (3326, 2)],
#  [(9, 1),
#   (11, 1),
#   (25, 1),
#   (73, 1),
#   (131, 1),
#   (168, 1),
#   (207, 3),
#   (232, 1),
#   (265, 1),
#   (267, 1),
#   (336, 1),
#   (382, 1),
#   (561, 1),
#   (708, 1),
#   (728, 1),
#   (741, 1),
#   (1037, 1),
#   (1159, 1),
#   (1356, 1),
#   (1472, 1),
#   (2505, 1),
#   (2826, 3),
#   (3327, 1),
#   (3328, 1),
#   (3329, 1)],
#  [(3, 1),
#   (51, 1),
#   (66, 1),
#   (78, 1),
#   (91, 1),
#   (94, 1),
#   (117, 1),
#   (581, 1),
#   (584, 1),
#   (2206, 1),
#   (2946, 1),
#   (3330, 1),
#   (3331, 1)],
#  [(16, 1),
#   (37, 4),
#   (73, 1),
#   (93, 1),
#   (291, 1),
#   (423, 1),
#   (467, 1),
#   (476, 1),
#   (478, 1),
#   (589, 1),
#   (602, 1),
#   (741, 1),
#   (1874, 1),
#   (2624, 1),
#   (3179, 1)],
#  [(13, 1),
#   (55, 1),
#   (66, 1),
#   (73, 1),
#   (83, 2),
#   (92, 1),
#   (162, 1),
#   (168, 1),
#   (261, 3),
#   (462, 1),
#   (679, 1),
#   (728, 1),
#   (2107, 1),
#   (2333, 1),
#   (2720, 1)],
#  [(5, 1),
#   (66, 1),
#   (102, 1),
#   (117, 1),
#   (257, 1),
#   (272, 1),
#   (466, 1),
#   (468, 1),
#   (898, 1),
#   (925, 1),
#   (1200, 1),
#   (2228, 1),
#   (2818, 1),
#   (3332, 1)],
#  [(22, 1),
#   (55, 1),
#   (73, 1),
#   (78, 1),
#   (102, 1),
#   (462, 1),
#   (507, 1),
#   (729, 1),
#   (3035, 1),
#   (3038, 1),
#   (3333, 1),
#   (3334, 2),
#   (3335, 1),
#   (3336, 1),
#   (3337, 1)],
#  [(78, 1),
#   (111, 1),
#   (272, 1),
#   (288, 1),
#   (299, 1),
#   (391, 2),
#   (657, 2),
#   (741, 1),
#   (1078, 1),
#   (2145, 1),
#   (2276, 1),
#   (3235, 1),
#   (3338, 1)],
#  [(13, 1),
#   (73, 1),
#   (121, 2),
#   (186, 1),
#   (232, 1),
#   (256, 1),
#   (258, 1),
#   (403, 2),
#   (423, 1),
#   (946, 1),
#   (1000, 1),
#   (1150, 1),
#   (3339, 1)],
#  [(22, 1),
#   (40, 1),
#   (73, 1),
#   (79, 1),
#   (141, 4),
#   (312, 1),
#   (346, 1),
#   (511, 1),
#   (671, 1),
#   (1194, 1),
#   (1814, 1),
#   (1877, 1),
#   (2729, 1),
#   (3340, 1),
#   (3341, 1)],
#  [(73, 1), (74, 1), (83, 1), (466, 1), (510, 2), (727, 1), (3342, 1)],
#  [(12, 1),
#   (19, 1),
#   (37, 2),
#   (113, 1),
#   (129, 1),
#   (172, 1),
#   (399, 1),
#   (435, 1),
#   (479, 1),
#   (666, 1),
#   (713, 1),
#   (1068, 1),
#   (1305, 1),
#   (2403, 1),
#   (3343, 1)],
#  [(11, 1),
#   (43, 1),
#   (73, 1),
#   (126, 1),
#   (143, 1),
#   (261, 3),
#   (424, 1),
#   (450, 1),
#   (466, 1),
#   (467, 1),
#   (748, 1),
#   (787, 1),
#   (956, 1),
#   (1038, 1),
#   (1212, 1),
#   (2435, 1),
#   (2836, 1),
#   (3344, 1)],
#  [(89, 1), (299, 1), (368, 1), (393, 1), (757, 1), (874, 1), (1054, 1)],
#  [(13, 1),
#   (73, 2),
#   (78, 2),
#   (99, 1),
#   (126, 2),
#   (127, 1),
#   (132, 1),
#   (141, 1),
#   (178, 1),
#   (222, 1),
#   (265, 1),
#   (300, 4),
#   (346, 1),
#   (350, 1),
#   (387, 1),
#   (423, 1),
#   (489, 1),
#   (805, 1),
#   (2141, 1),
#   (3345, 1)],
#  [(24, 1), (25, 1), (289, 1), (588, 1), (1025, 1), (3346, 1), (3347, 1)],
#  [(75, 1),
#   (393, 1),
#   (556, 1),
#   (1198, 1),
#   (1431, 1),
#   (1746, 1),
#   (1897, 1),
#   (2133, 1),
#   (3348, 1)],
#  [(13, 4),
#   (73, 1),
#   (207, 1),
#   (239, 1),
#   (299, 1),
#   (1546, 3),
#   (2097, 1),
#   (2422, 2),
#   (2502, 2),
#   (3349, 1),
#   (3350, 1),
#   (3351, 1),
#   (3352, 1)],
#  ...]

# %%
len(doc_term_matrix)
# Out:
# 100000

# %%
type(dictionary)
# Out:
# gensim.corpora.dictionary.Dictionary

# %%
print(dictionary)
# Out:
# Dictionary<34402 unique tokens: ['allergy', 'bear', 'cheddar', 'cheese', 'child']...>

# %%
# Getting the keys of dictionary that is the vocab
dictionary.token2id.keys()
# Out:
# dict_keys(['allergy', 'bear', 'cheddar', 'cheese', 'child', 'close', 'dairy', 'free', 'margarine', 'milk', 'noodle', 'packaging', 'place', 'product', 'resemblance', 'slice', 'stuff', 'substitute', 'substitution', 'time', 'wheat', 'wheatbased', 'year', 'baby', 'cereal', 'food', 'gobble', 'happy', 'lumpy', 'manufacturer', 'retailer', 'thick', 'yogurt', 'availble', 'brew', 'check', 'cocoa', 'coffee', 'cost', 'cup', 'difference', 'few', 'froth', 'heart', 'instant', 'liberal', 'logic', 'machine', 'next', 'nice', 'policy', 'powder', 'price', 'return', 'site', 'store', 'suggestion', 'surprised', 'thought', 'unit', 'well', 'avoid', 'believe', 'cleaning', 'comparable', 'diet', 'flavor', 'fluid', 'kerosene', 'list', 'mist', 'mountain', 'real', 'taste', 'bowl', 'cat', 'dressing', 'fishy', 'good', 'great', 'organic', 'pricey', 'right', 'smell', 'thumb', 'artichoke', 'awful', 'can', 'dish', 'friend', 'gritty', 'love', 'money', 'nasty', 'texture', 'waste', 'blueberry', 'desperate', 'fake', 'gross', 'none', 'overwhelming', 'terrible', 'wife', 'apple', 'disgusting', 'flavorless', 'actual', 'alright', 'different', 'grain', 'ingredient', 'lifestyle', 'lot', 'paleo', 'pink', 'slime', 'snack', 'bean', 'direct', 'member', 'mistake', 'prime', 'rectify', 'result', 'roasting', 'brand', 'control', 'first', 'kcup', 'last', 'poor', 'quality', 'trash', 'unusable', 'box', 'fine', 'shelf', 'short', 'third', 'timothys', 'water', 'weight', 'candy', 'crap', 'decade', 'gimicky', 'idea', 'lollypop', 'look', 'matter', 'particular', 'find', 'incorrect', 'label', 'receive', 'soup', 'website', 'chip', 'delivery', 'glennys', 'heck', 'refund', 'appearance', 'bag', 'cellophane', 'day', 'disappointed', 'horrible', 'individual', 'kid', 'popcorn', 'problem', 'rancid', 'tonight', 'chinese', 'cooking', 'experience', 'hand', 'home', 'pleasant', 'pleasure', 'restaurant', 'stir', 'tasty', 'break', 'company', 'difficult', 'engine', 'hard', 'hour', 'issue', 'model', 'piece', 'resolve', 'structure', 'train', 'unstable', 'banana', 'cashews', 'fruit', 'goodnessbr', 'mango', 'pack', 'peanut', 'pectin', 'raisin', 'seed', 'sunflower', 'trail', 'finicky', 'german', 'shepherd', 'unused', 'beef', 'blood', 'clot', 'enzyme', 'face', 'form', 'mask', 'operation', 'people', 'pork', 'scary', 'simple', 'sure', 'transglutaminase', 'vegan', 'baggie', 'dissapointing', 'large', 'much', 'orderbr', 'setup', 'strong', 'wonderful', 'absolute', 'address', 'bottle', 'companys', 'consumer', 'customer', 'design', 'disregard', 'failure', 'financial', 'imagine', 'opposite', 'parent', 'polar', 'spectrum', 'sprayer', 'trouble', 'wonder', 'attempt', 'bad', 'bite', 'cake', 'carrot', 'chemical', 'cinnamon', 'contest', 'entire', 'heavy', 'hope', 'item', 'least', 'life', 'opening', 'overtone', 'soap', 'thing', 'unappetizing', 'unpleasant', 'wrapper', 'butter', 'favorite', 'huge', 'boy', 'herb', 'month', 'vegetable', 'amazing', 'bar', 'raspberry', '10br', 'bucksbr', 'charge', 'dollar', 'drug', 'extra', 'highpriced', 'nerve', 'station', 'total', 'trip', 'walmart', 'weather', 'worth', 'case', 'code', 'date', 'interesting', 'multiple', 'package', 'alive', 'body', 'coconut', 'molding', 'potential', 'recall', 'shipment', 'subscription', 'avail', 'average', 'configuration', 'deal', 'espresso', 'esspresso', 'expensive', 'french', 'grand', 'grinder', 'hedge', 'preparation', 'press', 'reliability', 'reputation', 'shop', 'stick', 'thinking', 'available', 'belly', 'version', 'wise', 'container', 'drink', 'family', 'grape', 'less', 'lollipop', 'pomegranate', 'solution', 'weak', 'buying', 'high', 'mark', 'one', 'recent', 'review', 'thin', 'tin', 'amount', 'chore', 'clean', 'easy', 'effort', 'enough', 'exact', 'fresh', 'hernia', 'impossible', 'litter', 'many', 'muscle', 'necessary', 'owner', 'purchase', 'quick', 'scoop', 'scrape', 'sludge', 'sometime', 'step', 'strain', 'tell', 'unfortunate', 'assortment', 'devout', 'follower', 'grade', 'market', 'moldy', 'numerous', 'outlet', 'secondary', 'tasting', 'tertiary', 'bittersweet', ' ...

# %%
list(dictionary.token2id.keys())[:10]
# Out:
# ['allergy',
#  'bear',
#  'cheddar',
#  'cheese',
#  'child',
#  'close',
#  'dairy',
#  'free',
#  'margarine',
#  'milk']

# %% [markdown]
# # Building the LDA model

# %%
# Vreating the object for LDA model using gensim library
# Chunks for 1000 documents in each iteration
# 100 iterations 
LDA = gensim.models.ldamodel.LdaModel
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics = 10,random_state=101,
               chunksize=1000, passes = 50, iterations=100)

# %%
lda.mo
